# %% [markdown]
# - Soft Q Learning

# %%
# %matplotlib inline

import sys
import logging
import itertools
import copy

import numpy as np
np.random.seed(0)
import pandas as pd
import gym
import matplotlib.pyplot as plt
import torch
torch.manual_seed(0)
import torch.nn as nn
import torch.optim as optim
import torch.distributions as distributions

logging.basicConfig(level=logging.DEBUG,
        format='%(asctime)s [%(levelname)s] %(message)s',
        stream=sys.stdout, datefmt='%H:%M:%S')

# %%
env = gym.make('LunarLander-v2')
env.seed(0)
for key in vars(env):
    logging.info('%s: %s', key, vars(env)[key])
for key in vars(env.spec):
    logging.info('%s: %s', key, vars(env.spec)[key])
# Out:
# 10:16:22 [INFO] env: <LunarLander<LunarLander-v2>>
# 10:16:22 [INFO] action_space: Discrete(4)
# 10:16:22 [INFO] observation_space: Box([-inf -inf -inf -inf -inf -inf -inf -inf], [inf inf inf inf inf inf inf inf], (8,), float32)
# 10:16:22 [INFO] reward_range: (-inf, inf)
# 10:16:22 [INFO] metadata: {'render.modes': ['human', 'rgb_array'], 'video.frames_per_second': 50}
# 10:16:22 [INFO] _max_episode_steps: 1000
# 10:16:22 [INFO] _elapsed_steps: None
# 10:16:22 [INFO] id: LunarLander-v2
# 10:16:22 [INFO] entry_point: gym.envs.box2d:LunarLander
# 10:16:22 [INFO] reward_threshold: 200
# 10:16:22 [INFO] nondeterministic: False
# 10:16:22 [INFO] max_episode_steps: 1000
# 10:16:22 [INFO] _kwargs: {}
# 10:16:22 [INFO] _env_name: LunarLander

# %%
class DQNReplayer:
    def __init__(self, capacity):
        self.memory = pd.DataFrame(index=range(capacity),
                columns=['state', 'action', 'reward', 'next_state', 'done'])
        self.i = 0
        self.count = 0
        self.capacity = capacity

    def store(self, *args):
        self.memory.loc[self.i] = args
        self.i = (self.i + 1) % self.capacity
        self.count = min(self.count + 1, self.capacity)

    def sample(self, size):
        indices = np.random.choice(self.count, size=size)
        return (np.stack(self.memory.loc[indices, field]) for field in
                self.memory.columns)

# %%
class SQLAgent:
    def __init__(self, env):
        self.action_n = env.action_space.n
        self.gamma = 0.99

        self.replayer = DQNReplayer(10000)

        self.alpha = 0.02

        self.evaluate_net = self.build_net(
                input_size=env.observation_space.shape[0],
                hidden_sizes=[256, 256], output_size=self.action_n)
        self.optimizer = optim.Adam(self.evaluate_net.parameters(), lr=3e-4)
        self.loss = nn.MSELoss()

    def build_net(self, input_size, hidden_sizes, output_size):
        layers = []
        for input_size, output_size in zip(
                [input_size,] + hidden_sizes, hidden_sizes + [output_size,]):
            layers.append(nn.Linear(input_size, output_size))
            layers.append(nn.ReLU())
        layers = layers[:-1]
        model = nn.Sequential(*layers)
        return model

    def reset(self, mode=None):
        self.mode = mode
        if self.mode == 'train':
            self.trajectory = []
            self.target_net = copy.deepcopy(self.evaluate_net)

    def step(self, observation, reward, done):
        state_tensor = torch.as_tensor(observation,
                dtype=torch.float).squeeze(0)
        q_div_alpha_tensor = self.evaluate_net(state_tensor) / self.alpha
        v_div_alpha_tensor = torch.logsumexp(q_div_alpha_tensor, dim=-1,
                keepdim=True)
        prob_tensor = (q_div_alpha_tensor - v_div_alpha_tensor).exp()
        action_tensor = distributions.Categorical(prob_tensor).sample()
        action = action_tensor.item()
        if self.mode == 'train':
            self.trajectory += [observation, reward, done, action]
            if len(self.trajectory) >= 8:
                state, _, _, act, next_state, reward, done, _ = \
                        self.trajectory[-8:]
                self.replayer.store(state, act, reward, next_state, done)
            if self.replayer.count >= 500:
                self.learn()
        return action

    def close(self):
        pass

    def learn(self):
        # replay
        states, actions, rewards, next_states, dones = \
                self.replayer.sample(128) # replay transitions
        state_tensor = torch.as_tensor(states, dtype=torch.float)
        action_tensor = torch.as_tensor(actions, dtype=torch.long)
        reward_tensor = torch.as_tensor(rewards, dtype=torch.float)
        next_state_tensor = torch.as_tensor(next_states, dtype=torch.float)
        done_tensor = torch.as_tensor(dones, dtype=torch.float)

        # train
        next_q_tensor = self.target_net(next_state_tensor)
        next_v_tensor = self.alpha * torch.logsumexp(next_q_tensor / self.alpha, dim=-1)
        target_tensor = reward_tensor + self.gamma * (1. - done_tensor) * next_v_tensor
        pred_tensor = self.evaluate_net(state_tensor)
        q_tensor = pred_tensor.gather(1, action_tensor.unsqueeze(1)).squeeze(1)
        loss_tensor = self.loss(q_tensor, target_tensor.detach())
        self.optimizer.zero_grad()
        loss_tensor.backward()
        self.optimizer.step()


agent = SQLAgent(env)

# %%
def play_episode(env, agent, max_episode_steps=None, mode=None, render=False):
    observation, reward, done = env.reset(), 0., False
    agent.reset(mode=mode)
    episode_reward, elapsed_steps = 0., 0
    while True:
        action = agent.step(observation, reward, done)
        if render:
            env.render()
        if done:
            break
        observation, reward, done, _ = env.step(action)
        episode_reward += reward
        elapsed_steps += 1
        if max_episode_steps and elapsed_steps >= max_episode_steps:
            break
    agent.close()
    return episode_reward, elapsed_steps


logging.info('==== train ====')
episode_rewards = []
for episode in itertools.count():
    episode_reward, elapsed_steps = play_episode(env.unwrapped, agent,
            max_episode_steps=env._max_episode_steps, mode='train', render=True)
    episode_rewards.append(episode_reward)
    logging.debug('train episode %d: reward = %.2f, steps = %d',
            episode, episode_reward, elapsed_steps)
    if np.mean(episode_rewards[-10:]) > 250:
        break
plt.plot(episode_rewards)


logging.info('==== test ====')
episode_rewards = []
for episode in range(100):
    episode_reward, elapsed_steps = play_episode(env, agent, render=True)
    episode_rewards.append(episode_reward)
    logging.debug('test episode %d: reward = %.2f, steps = %d',
            episode, episode_reward, elapsed_steps)
logging.info('average episode reward = %.2f ± %.2f',
        np.mean(episode_rewards), np.std(episode_rewards))
# Out:
# 11:00:58 [INFO] ==== train ====
# C:\Users\voidwu\Anaconda3\envs\drl-py39\lib\site-packages\pandas\core\internals\blocks.py:938: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# 11:01:00 [DEBUG] train episode 0: reward = -461.18, steps = 83
# 11:01:01 [DEBUG] train episode 1: reward = -668.99, steps = 69
# 11:01:02 [DEBUG] train episode 2: reward = -458.32, steps = 73
# 11:01:03 [DEBUG] train episode 3: reward = -493.66, steps = 56
# 11:01:05 [DEBUG] train episode 4: reward = -546.61, steps = 76
# 11:01:06 [DEBUG] train episode 5: reward = -592.39, steps = 75
# 11:01:07 [DEBUG] train episode 6: reward = -591.07, steps = 68
# 11:02:21 [DEBUG] train episode 51: reward = -303.16, steps = 128
# 11:02:24 [DEBUG] train episode 52: reward = -274.90, steps = 191
# 11:02:26 [DEBUG] train episode 53: reward = -211.87, steps = 145
# 11:02:28 [DEBUG] train episode 54: reward = -307.96, steps = 105
# 11:02:30 [DEBUG] train episode 55: reward = -130.60, steps = 83
# 11:02:34 [DEBUG] train episode 56: reward = -230.91, steps = 265
# 11:02:40 [DEBUG] train episode 57: reward = -257.02, steps = 359
# 11:02:44 [DEBUG] train episode 58: reward = -329.02, steps = 227
# 11:02:49 [DEBUG] train episode 59: reward = -372.49, steps = 339
# 11:02:52 [DEBUG] train episode 60: reward = -408.30, steps = 179
# 11:03:07 [DEBUG] train episode 61: reward = -309.62, steps = 891
# 11:03:14 [DEBUG] train episode 62: reward = -391.57, steps = 408
# 11:03:17 [DEBUG] train episode 63: reward = -66.08, steps = 155
# 11:03:23 [DEBUG] train episode 64: reward = -268.91, steps = 391
# 11:03:31 [DEBUG] train episode 65: reward = -244.28, steps = 486
# 11:03:36 [DEBUG] train episode 66: reward = -131.04, steps = 292
# 11:03:47 [DEBUG] train episode 67: reward = -252.81, steps = 620
# 11:04:00 [DEBUG] train episode 68: reward = -259.01, steps = 788
# 11:04:05 [DEBUG] train episode 69: reward = -55.11, steps = 327
# 11:04:22 [DEBUG] train episode 70: reward = -152.72, steps = 1000
# 11:04:39 [DEBUG] train episode 71: reward = -194.41, steps = 1000
# 11:04:55 [DEBUG] train episode 72: reward = -154.45, steps = 1000
# 11:05:12 [DEBUG] train episode 73: reward = -157.02, steps = 1000
# 11:05:29 [DEBUG] train episode 74: reward = -194.18, steps = 1000
# 11:05:45 [DEBUG] train episode 75: reward = -203.26, steps = 1000
# 11:06:02 [DEBUG] train episode 76: reward = -137.28, steps = 1000
# 11:06:19 [DEBUG] train episode 77: reward = -107.00, steps = 1000
# 11:06:35 [DEBUG] train episode 78: reward = -153.51, steps = 1000
# 11:06:52 [DEBUG] train episode 79: reward = -135.89, steps = 1000
# 11:07:09 [DEBUG] train episode 80: reward = -104.98, steps = 1000
# 11:07:25 [DEBUG] train episode 81: reward = -168.17, steps = 1000
# 11:07:42 [DEBUG] train episode 82: reward = -146.06, steps = 1000
# 11:07:44 [DEBUG] train episode 83: reward = -171.05, steps = 127
# 11:08:01 [DEBUG] train episode 84: reward = -158.02, steps = 1000
# 11:08:18 [DEBUG] train episode 85: reward = -168.54, steps = 1000
# 11:08:34 [DEBUG] train episode 86: reward = -163.43, steps = 1000
# 11:08:51 [DEBUG] train episode 87: reward = -168.95, steps = 1000
# 11:09:08 [DEBUG] train episode 88: reward = -179.07, steps = 1000
# 11:09:09 [DEBUG] train episode 89: reward = -178.74, steps = 114
# 11:09:11 [DEBUG] train episode 90: reward = -191.65, steps = 123
# 11:09:14 [DEBUG] train episode 91: reward = -184.54, steps = 159
# 11:09:31 [DEBUG] train episode 92: reward = -154.66, steps = 1000
# 11:09:32 [DEBUG] train episode 93: reward = -103.84, steps = 86
# 11:37:57 [DEBUG] train episode 224: reward = -15.01, steps = 1000
# 11:38:14 [DEBUG] train episode 225: reward = -9.62, steps = 1000
# 11:38:30 [DEBUG] train episode 226: reward = -10.44, steps = 1000
# 11:38:34 [DEBUG] train episode 227: reward = -108.05, steps = 201
# 11:38:50 [DEBUG] train episode 228: reward = -14.79, steps = 1000
# 11:39:07 [DEBUG] train episode 229: reward = 1.50, steps = 1000
# 11:39:24 [DEBUG] train episode 230: reward = -29.00, steps = 1000
# 11:39:40 [DEBUG] train episode 231: reward = -38.18, steps = 1000
# 11:39:57 [DEBUG] train episode 232: reward = -25.91, steps = 1000
# 11:40:14 [DEBUG] train episode 233: reward = -42.96, steps = 1000
# 11:40:30 [DEBUG] train episode 234: reward = -34.84, steps = 1000
# 11:40:46 [DEBUG] train episode 235: reward = -82.28, steps = 959
# 11:41:03 [DEBUG] train episode 236: reward = -33.81, steps = 1000
# 11:41:20 [DEBUG] train episode 237: reward = -41.75, steps = 1000
# 11:41:36 [DEBUG] train episode 238: reward = -10.92, steps = 1000
# 11:41:53 [DEBUG] train episode 239: reward = 21.13, steps = 1000
# 11:42:10 [DEBUG] train episode 240: reward = 21.35, steps = 1000
# 11:42:26 [DEBUG] train episode 241: reward = -40.41, steps = 1000
# 11:42:43 [DEBUG] train episode 242: reward = -33.77, steps = 1000
# 11:43:00 [DEBUG] train episode 243: reward = -4.40, steps = 1000
# 11:43:05 [DEBUG] train episode 244: reward = -48.37, steps = 339
# 11:43:22 [DEBUG] train episode 245: reward = -15.08, steps = 1000
# 11:43:39 [DEBUG] train episode 246: reward = -38.45, steps = 1000
# 11:43:55 [DEBUG] train episode 247: reward = 25.07, steps = 1000
# 11:44:12 [DEBUG] train episode 248: reward = 5.94, steps = 1000
# 11:44:29 [DEBUG] train episode 249: reward = -7.28, steps = 1000
# 11:44:45 [DEBUG] train episode 250: reward = -25.01, steps = 1000
# 11:45:02 [DEBUG] train episode 251: reward = 4.91, steps = 1000
# 11:45:19 [DEBUG] train episode 252: reward = 0.57, steps = 1000
# 11:45:35 [DEBUG] train episode 253: reward = 16.33, steps = 1000
# 11:45:52 [DEBUG] train episode 254: reward = -38.30, steps = 1000
# 11:46:09 [DEBUG] train episode 255: reward = -6.45, steps = 1000
# 11:46:25 [DEBUG] train episode 256: reward = 26.63, steps = 1000
# 11:46:42 [DEBUG] train episode 257: reward = -9.23, steps = 1000
# 11:46:59 [DEBUG] train episode 258: reward = -33.78, steps = 1000
# 11:47:15 [DEBUG] train episode 259: reward = -47.03, steps = 1000
# 11:47:32 [DEBUG] train episode 260: reward = -14.98, steps = 1000
# 11:47:49 [DEBUG] train episode 261: reward = 7.35, steps = 1000
# 11:48:05 [DEBUG] train episode 262: reward = -9.48, steps = 1000
# 11:48:22 [DEBUG] train episode 263: reward = -5.92, steps = 1000
# 11:48:39 [DEBUG] train episode 264: reward = -38.49, steps = 1000
# 11:48:55 [DEBUG] train episode 265: reward = 7.57, steps = 1000
# 11:49:12 [DEBUG] train episode 266: reward = -10.89, steps = 1000
# 11:49:29 [DEBUG] train episode 267: reward = -14.59, steps = 1000
# 11:49:45 [DEBUG] train episode 268: reward = -16.11, steps = 1000
# 11:50:02 [DEBUG] train episode 269: reward = -20.12, steps = 1000
# 11:50:19 [DEBUG] train episode 270: reward = 1.05, steps = 1000
# 11:50:35 [DEBUG] train episode 271: reward = -3.92, steps = 1000
# 11:50:52 [DEBUG] train episode 272: reward = -30.92, steps = 1000
# 11:51:09 [DEBUG] train episode 273: reward = 23.03, steps = 1000
# 11:51:25 [DEBUG] train episode 274: reward = -8.92, steps = 1000
# 11:51:42 [DEBUG] train episode 275: reward = -2.92, steps = 1000
# 11:51:59 [DEBUG] train episode 276: reward = -22.41, steps = 1000
# 11:52:16 [DEBUG] train episode 277: reward = 6.99, steps = 1000
# 11:52:32 [DEBUG] train episode 278: reward = -26.22, steps = 1000
# 11:52:49 [DEBUG] train episode 279: reward = 19.68, steps = 1000
# 11:52:53 [DEBUG] train episode 280: reward = -75.09, steps = 270
# 11:53:10 [DEBUG] train episode 281: reward = -12.96, steps = 1000
# 11:53:27 [DEBUG] train episode 282: reward = -30.30, steps = 1000
# 11:53:29 [DEBUG] train episode 283: reward = -208.08, steps = 122
# 11:53:45 [DEBUG] train episode 284: reward = -0.37, steps = 1000
# 11:54:02 [DEBUG] train episode 285: reward = -33.22, steps = 1000
# 11:54:19 [DEBUG] train episode 286: reward = -35.99, steps = 1000
# 11:54:35 [DEBUG] train episode 287: reward = -49.66, steps = 1000
# 11:54:52 [DEBUG] train episode 288: reward = -8.03, steps = 1000
# 11:55:09 [DEBUG] train episode 289: reward = 23.98, steps = 1000
# 11:55:11 [DEBUG] train episode 290: reward = -132.84, steps = 114
# 11:55:27 [DEBUG] train episode 291: reward = -38.06, steps = 1000
# 11:55:44 [DEBUG] train episode 292: reward = 21.33, steps = 1000
# 11:56:01 [DEBUG] train episode 293: reward = -22.60, steps = 1000
# 11:56:17 [DEBUG] train episode 294: reward = -10.88, steps = 1000
# 11:56:34 [DEBUG] train episode 295: reward = 24.14, steps = 1000
# 11:56:51 [DEBUG] train episode 296: reward = -41.90, steps = 1000
# 11:57:07 [DEBUG] train episode 297: reward = 5.11, steps = 1000
# 11:57:24 [DEBUG] train episode 298: reward = 16.61, steps = 1000
# 11:57:26 [DEBUG] train episode 299: reward = -14.50, steps = 143
# 11:57:43 [DEBUG] train episode 300: reward = -29.94, steps = 1000
# 11:58:00 [DEBUG] train episode 301: reward = 25.06, steps = 1000
# 11:58:16 [DEBUG] train episode 302: reward = -13.24, steps = 1000
# 11:58:32 [DEBUG] train episode 303: reward = 120.57, steps = 906
# 11:58:48 [DEBUG] train episode 304: reward = -6.20, steps = 1000
# 11:59:05 [DEBUG] train episode 305: reward = -14.57, steps = 1000
# 11:59:22 [DEBUG] train episode 306: reward = 31.66, steps = 1000
# 11:59:37 [DEBUG] train episode 307: reward = 172.61, steps = 921
# 11:59:54 [DEBUG] train episode 308: reward = 4.70, steps = 1000
# 12:00:06 [DEBUG] train episode 309: reward = 137.85, steps = 739
# 12:00:23 [DEBUG] train episode 310: reward = 13.41, steps = 1000
# 12:16:50 [DEBUG] train episode 443: reward = 259.47, steps = 236
# 12:16:56 [DEBUG] train episode 444: reward = 247.81, steps = 364
# 12:17:00 [DEBUG] train episode 445: reward = 267.77, steps = 226
# 12:17:04 [DEBUG] train episode 446: reward = 281.22, steps = 279
# 12:17:12 [DEBUG] train episode 447: reward = 230.81, steps = 451
# 12:17:15 [DEBUG] train episode 448: reward = 1.93, steps = 222
# 12:17:19 [DEBUG] train episode 449: reward = 258.51, steps = 225
# 12:17:24 [DEBUG] train episode 450: reward = 266.29, steps = 271
# 12:17:28 [DEBUG] train episode 451: reward = 227.01, steps = 233
# 12:17:32 [DEBUG] train episode 452: reward = 230.10, steps = 246
# 12:17:35 [DEBUG] train episode 453: reward = -39.56, steps = 195
# 12:17:52 [DEBUG] train episode 454: reward = 5.59, steps = 1000
# 12:17:56 [DEBUG] train episode 455: reward = -28.94, steps = 234
# 12:17:59 [DEBUG] train episode 456: reward = 262.87, steps = 213
# 12:18:03 [DEBUG] train episode 457: reward = 268.18, steps = 220
# 12:18:07 [DEBUG] train episode 458: reward = 276.96, steps = 272
# 12:18:11 [DEBUG] train episode 459: reward = 265.43, steps = 242
# 12:18:18 [DEBUG] train episode 460: reward = 249.53, steps = 385
# 12:18:21 [DEBUG] train episode 461: reward = 240.35, steps = 207
# 12:18:28 [DEBUG] train episode 462: reward = 228.34, steps = 414
# 12:18:32 [DEBUG] train episode 463: reward = 271.43, steps = 209
# 12:18:39 [DEBUG] train episode 464: reward = 169.79, steps = 427
# 12:18:47 [DEBUG] train episode 465: reward = 262.11, steps = 498
# 12:18:52 [DEBUG] train episode 466: reward = 289.58, steps = 262
# 12:18:52 [INFO] ==== test ====
# 12:18:55 [DEBUG] test episode 0: reward = 234.96, steps = 198
# 12:19:00 [DEBUG] test episode 1: reward = 25.61, steps = 302
# 12:19:05 [DEBUG] test episode 2: reward = 0.64, steps = 317
# 12:19:12 [DEBUG] test episode 3: reward = 214.61, steps = 384
# 12:19:17 [DEBUG] test episode 4: reward = 248.08, steps = 323
# 12:19:21 [DEBUG] test episode 5: reward = 269.70, steps = 250
# 12:19:26 [DEBUG] test episode 6: reward = 5.12, steps = 286
# 12:19:31 [DEBUG] test episode 7: reward = 288.05, steps = 270
# 12:19:36 [DEBUG] test episode 8: reward = 261.30, steps = 324
# 12:19:53 [DEBUG] test episode 9: reward = 88.41, steps = 1000
# 12:19:58 [DEBUG] test episode 10: reward = 229.83, steps = 314
# 12:20:02 [DEBUG] test episode 11: reward = 33.09, steps = 261
# 12:20:09 [DEBUG] test episode 12: reward = 223.92, steps = 405
# 12:20:14 [DEBUG] test episode 13: reward = 230.19, steps = 284
# 12:20:18 [DEBUG] test episode 14: reward = 272.05, steps = 264
# 12:20:24 [DEBUG] test episode 15: reward = 258.86, steps = 340
# 12:20:28 [DEBUG] test episode 16: reward = 231.69, steps = 275
# 12:20:33 [DEBUG] test episode 17: reward = 267.90, steps = 284
# 12:20:39 [DEBUG] test episode 18: reward = 235.27, steps = 346
# 12:20:45 [DEBUG] test episode 19: reward = 232.54, steps = 355
# 12:20:50 [DEBUG] test episode 20: reward = -68.90, steps = 300
# 12:20:55 [DEBUG] test episode 21: reward = 219.04, steps = 285
# 12:21:00 [DEBUG] test episode 22: reward = 212.78, steps = 321
# 12:21:06 [DEBUG] test episode 23: reward = 213.48, steps = 328
# 12:21:22 [DEBUG] test episode 24: reward = 132.97, steps = 1000
# 12:21:29 [DEBUG] test episode 25: reward = 217.22, steps = 374
# 12:21:32 [DEBUG] test episode 26: reward = 272.63, steps = 197
# 12:21:42 [DEBUG] test episode 27: reward = 187.06, steps = 585
# 12:21:45 [DEBUG] test episode 28: reward = 258.41, steps = 200
# 12:21:50 [DEBUG] test episode 29: reward = 236.06, steps = 318
# 12:21:56 [DEBUG] test episode 30: reward = 226.38, steps = 347
# 12:22:13 [DEBUG] test episode 31: reward = 130.39, steps = 1000
# 12:22:16 [DEBUG] test episode 32: reward = 282.57, steps = 207
# 12:22:20 [DEBUG] test episode 33: reward = 212.51, steps = 237
# 12:22:23 [DEBUG] test episode 34: reward = 19.24, steps = 199
# 12:22:27 [DEBUG] test episode 35: reward = 256.20, steps = 238
# 12:22:32 [DEBUG] test episode 36: reward = 264.02, steps = 273
# 12:22:35 [DEBUG] test episode 37: reward = -35.82, steps = 184
# 12:22:38 [DEBUG] test episode 38: reward = -45.12, steps = 199
# 12:22:42 [DEBUG] test episode 39: reward = 1.90, steps = 202
# 12:22:46 [DEBUG] test episode 40: reward = 272.25, steps = 261
# 12:22:49 [DEBUG] test episode 41: reward = 237.26, steps = 196
# 12:22:55 [DEBUG] test episode 42: reward = 8.79, steps = 343
# 12:23:01 [DEBUG] test episode 43: reward = -16.07, steps = 351
# 12:23:06 [DEBUG] test episode 44: reward = 262.17, steps = 319
# 12:23:23 [DEBUG] test episode 45: reward = 142.81, steps = 1000
# 12:23:27 [DEBUG] test episode 46: reward = 281.00, steps = 210
# 12:23:33 [DEBUG] test episode 47: reward = 236.30, steps = 405
# 12:23:39 [DEBUG] test episode 48: reward = 227.98, steps = 337
# 12:23:43 [DEBUG] test episode 49: reward = 255.55, steps = 234
# 12:23:48 [DEBUG] test episode 50: reward = 247.54, steps = 308
# 12:23:52 [DEBUG] test episode 51: reward = -30.50, steps = 239
# 12:23:57 [DEBUG] test episode 52: reward = 180.74, steps = 277
# 12:24:01 [DEBUG] test episode 53: reward = -27.00, steps = 232
# 12:24:05 [DEBUG] test episode 54: reward = 243.09, steps = 290
# 12:24:11 [DEBUG] test episode 55: reward = 192.56, steps = 349
# 12:24:15 [DEBUG] test episode 56: reward = 253.26, steps = 212
# 12:24:21 [DEBUG] test episode 57: reward = 236.85, steps = 385
# 12:24:25 [DEBUG] test episode 58: reward = 267.67, steps = 199
# 12:24:30 [DEBUG] test episode 59: reward = 252.06, steps = 317
# 12:24:35 [DEBUG] test episode 60: reward = 256.58, steps = 299
# 12:24:40 [DEBUG] test episode 61: reward = 276.57, steps = 299
# 12:24:45 [DEBUG] test episode 62: reward = 204.38, steps = 310
# 12:24:51 [DEBUG] test episode 63: reward = 235.46, steps = 339
# 12:24:56 [DEBUG] test episode 64: reward = 10.83, steps = 317
# 12:25:02 [DEBUG] test episode 65: reward = 233.23, steps = 334
# 12:25:08 [DEBUG] test episode 66: reward = 237.36, steps = 395
# 12:25:16 [DEBUG] test episode 67: reward = 211.91, steps = 456
# 12:25:22 [DEBUG] test episode 68: reward = 231.77, steps = 339
# 12:25:27 [DEBUG] test episode 69: reward = 226.55, steps = 336
# 12:25:44 [DEBUG] test episode 70: reward = 99.42, steps = 1000
# 12:25:49 [DEBUG] test episode 71: reward = 212.00, steps = 287
# 12:25:54 [DEBUG] test episode 72: reward = 4.73, steps = 305
# 12:25:59 [DEBUG] test episode 73: reward = 241.29, steps = 331
# 12:26:04 [DEBUG] test episode 74: reward = 216.47, steps = 269
# 12:26:20 [DEBUG] test episode 75: reward = 98.87, steps = 1000
# 12:26:25 [DEBUG] test episode 76: reward = 207.99, steps = 270
# 12:26:31 [DEBUG] test episode 77: reward = 221.07, steps = 369
# 12:26:35 [DEBUG] test episode 78: reward = 256.94, steps = 236
# 12:26:43 [DEBUG] test episode 79: reward = 167.99, steps = 486
# 12:26:46 [DEBUG] test episode 80: reward = 257.07, steps = 196
# 12:26:51 [DEBUG] test episode 81: reward = 230.94, steps = 253
# 12:26:56 [DEBUG] test episode 82: reward = 211.52, steps = 329
# 12:27:02 [DEBUG] test episode 83: reward = 216.79, steps = 375
# 12:27:10 [DEBUG] test episode 84: reward = 191.74, steps = 443
# 12:27:17 [DEBUG] test episode 85: reward = 193.05, steps = 428
# 12:27:24 [DEBUG] test episode 86: reward = 204.85, steps = 412
# 12:27:29 [DEBUG] test episode 87: reward = 262.85, steps = 301
# 12:27:33 [DEBUG] test episode 88: reward = 261.62, steps = 219
# 12:27:38 [DEBUG] test episode 89: reward = -12.16, steps = 345
# 12:27:44 [DEBUG] test episode 90: reward = -3.08, steps = 325
# 12:27:47 [DEBUG] test episode 91: reward = -6.03, steps = 197
# 12:27:52 [DEBUG] test episode 92: reward = 232.47, steps = 296
# 12:27:57 [DEBUG] test episode 93: reward = 210.12, steps = 293
# 12:28:01 [DEBUG] test episode 94: reward = -41.84, steps = 220
# 12:28:07 [DEBUG] test episode 95: reward = 10.98, steps = 365
# 12:28:12 [DEBUG] test episode 96: reward = 210.35, steps = 329
# 12:28:19 [DEBUG] test episode 97: reward = 200.29, steps = 396
# 12:28:23 [DEBUG] test episode 98: reward = 20.72, steps = 222
# 12:28:27 [DEBUG] test episode 99: reward = 265.97, steps = 293
# 12:28:27 [INFO] average episode reward = 177.39 ± 102.48
# 12:28:27 [DEBUG] findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0.
# 12:28:27 [DEBUG] findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymReg.ttf) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymBol.ttf) normal normal 700 normal>) = 10.335
# 12:28:27 [DEBUG] findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Italic.ttf) italic normal 400 normal>) = 11.05
# 12:28:27 [DEBUG] findfont: score(<Font 'STIXNonUnicode' (STIXNonUni.ttf) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Bold.ttf) normal normal 700 normal>) = 0.33499999999999996
# 12:28:27 [DEBUG] findfont: score(<Font 'STIXGeneral' (STIXGeneralBolIta.ttf) italic normal 700 normal>) = 11.335
# 12:28:27 [DEBUG] findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Oblique.ttf) oblique normal 400 normal>) = 1.05
# 12:28:27 [DEBUG] findfont: score(<Font 'DejaVu Sans' (DejaVuSans-BoldOblique.ttf) oblique normal 700 normal>) = 1.335
# 12:28:27 [DEBUG] findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymReg.ttf) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'cmsy10' (cmsy10.ttf) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBol.ttf) normal normal 700 normal>) = 10.335
# 12:28:27 [DEBUG] findfont: score(<Font 'cmmi10' (cmmi10.ttf) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-Bold.ttf) normal normal 700 normal>) = 10.335
# 12:28:27 [DEBUG] findfont: score(<Font 'STIXSizeFourSym' (STIXSizFourSymBol.ttf) normal normal 700 normal>) = 10.335
# 12:28:27 [DEBUG] findfont: score(<Font 'STIXSizeThreeSym' (STIXSizThreeSymBol.ttf) normal normal 700 normal>) = 10.335
# 12:28:27 [DEBUG] findfont: score(<Font 'cmex10' (cmex10.ttf) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'STIXNonUnicode' (STIXNonUniBolIta.ttf) italic normal 700 normal>) = 11.335
# 12:28:27 [DEBUG] findfont: score(<Font 'STIXSizeFiveSym' (STIXSizFiveSymReg.ttf) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'DejaVu Serif Display' (DejaVuSerifDisplay.ttf) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Bold.ttf) normal normal 700 normal>) = 10.335
# 12:28:27 [DEBUG] findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymReg.ttf) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'cmtt10' (cmtt10.ttf) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'STIXGeneral' (STIXGeneralBol.ttf) normal normal 700 normal>) = 10.335
# 12:28:27 [DEBUG] findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymReg.ttf) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'cmb10' (cmb10.ttf) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'STIXGeneral' (STIXGeneral.ttf) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'STIXNonUnicode' (STIXNonUniIta.ttf) italic normal 400 normal>) = 11.05
# 12:28:27 [DEBUG] findfont: score(<Font 'DejaVu Serif' (DejaVuSerif-BoldItalic.ttf) italic normal 700 normal>) = 11.335
# 12:28:27 [DEBUG] findfont: score(<Font 'DejaVu Serif' (DejaVuSerif.ttf) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'STIXGeneral' (STIXGeneralItalic.ttf) italic normal 400 normal>) = 11.05
# 12:28:27 [DEBUG] findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-BoldOblique.ttf) oblique normal 700 normal>) = 11.335
# 12:28:27 [DEBUG] findfont: score(<Font 'DejaVu Sans Display' (DejaVuSansDisplay.ttf) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymBol.ttf) normal normal 700 normal>) = 10.335
# 12:28:27 [DEBUG] findfont: score(<Font 'DejaVu Sans' (DejaVuSans.ttf) normal normal 400 normal>) = 0.05
# 12:28:27 [DEBUG] findfont: score(<Font 'cmr10' (cmr10.ttf) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono-Oblique.ttf) oblique normal 400 normal>) = 11.05
# 12:28:27 [DEBUG] findfont: score(<Font 'DejaVu Sans Mono' (DejaVuSansMono.ttf) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'cmss10' (cmss10.ttf) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'Blackadder ITC' (ITCBLKAD.TTF) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'Ink Free' (Inkfree.ttf) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'Verdana' (verdanaz.ttf) italic normal 700 normal>) = 4.971363636363637
# 12:28:27 [DEBUG] findfont: score(<Font 'Candara' (Candara.ttf) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'Gloucester MT Extra Condensed' (GLECB.TTF) normal normal 400 condensed>) = 10.25
# 12:28:27 [DEBUG] findfont: score(<Font 'Segoe UI' (seguisbi.ttf) italic normal 600 normal>) = 11.24
# 12:28:27 [DEBUG] findfont: score(<Font 'Microsoft JhengHei' (msjhbd.ttc) normal normal 700 normal>) = 10.335
# 12:28:27 [DEBUG] findfont: score(<Font 'Century Schoolbook' (CENSCBK.TTF) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'Franklin Gothic Heavy' (FRAHV.TTF) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'Curlz MT' (CURLZ___.TTF) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'Arial' (arial.ttf) normal normal 400 normal>) = 6.413636363636363
# 12:28:27 [DEBUG] findfont: score(<Font 'MT Extra' (MTEXTRA.TTF) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'STKaiti' (STKAITI.TTF) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'Verdana' (verdanai.ttf) italic normal 400 normal>) = 4.6863636363636365
# 12:28:27 [DEBUG] findfont: score(<Font 'Consolas' (consolaz.ttf) italic normal 700 normal>) = 11.335
# 12:28:27 [DEBUG] findfont: score(<Font 'Harrington' (HARNGTON.TTF) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'Bookman Old Style' (BOOKOSI.TTF) italic normal 300 normal>) = 11.145
# 12:28:27 [DEBUG] findfont: score(<Font 'Eras Medium ITC' (ERASMD.TTF) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'Malgun Gothic' (malgunsl.ttf) normal normal 300 normal>) = 10.145
# 12:28:27 [DEBUG] findfont: score(<Font 'Tw Cen MT' (TCMI____.TTF) italic normal 400 normal>) = 11.05
# 12:28:27 [DEBUG] findfont: score(<Font 'Bodoni MT' (BOD_CI.TTF) italic normal 400 condensed>) = 11.25
# 12:28:27 [DEBUG] findfont: score(<Font 'Sitka Small' (SitkaB.ttc) normal normal 700 normal>) = 10.335
# 12:28:27 [DEBUG] findfont: score(<Font 'Dubai' (DUBAI-BOLD.TTF) normal normal 700 normal>) = 10.335
# 12:28:27 [DEBUG] findfont: score(<Font 'Cambria' (cambriai.ttf) italic normal 400 normal>) = 11.05
# 12:28:27 [DEBUG] findfont: score(<Font 'Freestyle Script' (FREESCPT.TTF) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'Gill Sans MT' (GIL_____.TTF) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'Webdings' (webdings.ttf) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'Tahoma' (tahoma.ttf) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'Malgun Gothic' (malgun.ttf) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'Brush Script MT' (BRUSHSCI.TTF) italic normal 400 normal>) = 11.05
# 12:28:27 [DEBUG] findfont: score(<Font 'Yu Gothic' (YuGothB.ttc) normal normal 700 normal>) = 10.335
# 12:28:27 [DEBUG] findfont: score(<Font 'Corbel' (corbelli.ttf) italic normal 300 normal>) = 11.145
# 12:28:27 [DEBUG] findfont: score(<Font 'Matura MT Script Capitals' (MATURASC.TTF) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'Lucida Calligraphy' (LCALLIG.TTF) italic normal 400 normal>) = 11.05
# 12:28:27 [DEBUG] findfont: score(<Font 'Tw Cen MT Condensed Extra Bold' (TCCEB.TTF) normal normal 400 condensed>) = 10.25
# 12:28:27 [DEBUG] findfont: score(<Font 'Rockwell Condensed' (ROCCB___.TTF) normal normal 700 condensed>) = 10.535
# 12:28:27 [DEBUG] findfont: score(<Font 'Felix Titling' (FELIXTI.TTF) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'Tw Cen MT' (TCM_____.TTF) normal normal 400 normal>) = 10.05
# 12:28:27 [DEBUG] findfont: score(<Font 'Lucida Bright' (LBRITED.TTF) normal normal 600 normal>) = 10.24
# 12:28:27 [DEBUG] findfont: score(<Font 'Sitka Small' (SitkaI.ttc) italic normal 400 normal>) = 11.05
# 12:28:27 [DEBUG] findfont: score(<Font 'Lucida Sans' (LSANSD.TTF) normal normal 600 normal>) = 10.24
# 12:28:28 [DEBUG] findfont: score(<Font 'Javanese Text' (javatext.ttf) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Perpetua' (PERBI___.TTF) italic normal 700 normal>) = 11.335
# 12:28:28 [DEBUG] findfont: score(<Font 'Magneto' (MAGNETOB.TTF) normal normal 700 normal>) = 10.335
# 12:28:28 [DEBUG] findfont: score(<Font 'Bell MT' (BELL.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Calisto MT' (CALISTBI.TTF) italic normal 700 normal>) = 11.335
# 12:28:28 [DEBUG] findfont: score(<Font 'Imprint MT Shadow' (IMPRISHA.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Rockwell' (ROCK.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Constantia' (constan.ttf) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Book Antiqua' (ANTQUAB.TTF) normal normal 700 normal>) = 10.335
# 12:28:28 [DEBUG] findfont: score(<Font 'FZShuTi' (FZSTK.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Poor Richard' (POORICH.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Sylfaen' (sylfaen.ttf) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Franklin Gothic Demi Cond' (FRADMCN.TTF) normal normal 400 condensed>) = 10.25
# 12:28:28 [DEBUG] findfont: score(<Font 'Calisto MT' (CALISTI.TTF) italic normal 400 normal>) = 11.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Lucida Console' (lucon.ttf) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Palatino Linotype' (pala.ttf) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Eras Demi ITC' (ERASDEMI.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Georgia' (georgiai.ttf) italic normal 400 normal>) = 11.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Copperplate Gothic Bold' (COPRGTB.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Garamond' (GARAIT.TTF) italic normal 400 normal>) = 11.05
# ...
# 12:28:28 [DEBUG] findfont: score(<Font 'Rockwell Extra Bold' (ROCKEB.TTF) normal normal 800 normal>) = 10.43
# 12:28:28 [DEBUG] findfont: score(<Font 'Segoe MDL2 Assets' (segmdl2.ttf) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Onyx' (ONYX.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Tw Cen MT Condensed' (TCCM____.TTF) normal normal 400 condensed>) = 10.25
# 12:28:28 [DEBUG] findfont: score(<Font 'Microsoft JhengHei' (msjh.ttc) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Candara' (Candara.ttf) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Dubai' (DUBAI-LIGHT.TTF) normal normal 300 normal>) = 10.145
# 12:28:28 [DEBUG] findfont: score(<Font 'Webdings' (webdings.ttf) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Gill Sans MT Condensed' (GILC____.TTF) normal normal 400 condensed>) = 10.25
# 12:28:28 [DEBUG] findfont: score(<Font 'Copperplate Gothic Light' (COPRGTL.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Arial Rounded MT Bold' (ARLRDBD.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'MV Boli' (mvboli.ttf) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Gill Sans Ultra Bold Condensed' (GILLUBCD.TTF) normal normal 400 condensed>) = 10.25
# 12:28:28 [DEBUG] findfont: score(<Font 'Lucida Fax' (LFAXI.TTF) italic normal 400 normal>) = 11.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Arial' (arialbd.ttf) normal normal 700 normal>) = 6.698636363636363
# 12:28:28 [DEBUG] findfont: score(<Font 'Bodoni MT' (BOD_R.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Modern No. 20' (MOD20.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Sitka Small' (Sitka.ttc) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Bell MT' (BELLI.TTF) italic normal 400 normal>) = 11.05
# 12:28:28 [DEBUG] findfont: score(<Font 'DengXian' (Dengb.ttf) normal normal 700 normal>) = 10.335
# 12:28:28 [DEBUG] findfont: score(<Font 'Arial' (ariali.ttf) italic normal 400 normal>) = 7.413636363636363
# 12:28:28 [DEBUG] findfont: score(<Font 'Arial' (ARIALN.TTF) normal normal 400 condensed>) = 6.613636363636363
# 12:28:28 [DEBUG] findfont: score(<Font 'Bell MT' (BELLB.TTF) normal normal 700 normal>) = 10.335
# 12:28:28 [DEBUG] findfont: score(<Font 'Modern No. 20' (MOD20.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Leelawadee UI' (LeelawUI.ttf) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Leelawadee UI' (LeelaUIb.ttf) normal normal 700 normal>) = 10.335
# 12:28:28 [DEBUG] findfont: score(<Font 'Harlow Solid Italic' (HARLOWSI.TTF) italic normal 400 normal>) = 11.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Broadway' (BROADW.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Lucida Sans Typewriter' (LTYPEB.TTF) normal normal 600 normal>) = 10.24
# 12:28:28 [DEBUG] findfont: score(<Font 'Haettenschweiler' (HATTEN.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Lucida Fax' (LFAXD.TTF) normal normal 600 normal>) = 10.24
# 12:28:28 [DEBUG] findfont: score(<Font 'Verdana' (verdanab.ttf) normal normal 700 normal>) = 3.9713636363636367
# 12:28:28 [DEBUG] findfont: score(<Font 'Juice ITC' (JUICE___.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Arial' (arialbi.ttf) italic normal 700 normal>) = 7.698636363636363
# 12:28:28 [DEBUG] findfont: score(<Font 'Gill Sans MT' (GILBI___.TTF) italic normal 700 normal>) = 11.335
# 12:28:28 [DEBUG] findfont: score(<Font 'Mistral' (MISTRAL.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'SimHei' (simhei.ttf) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Book Antiqua' (ANTQUAB.TTF) normal normal 700 normal>) = 10.335
# 12:28:28 [DEBUG] findfont: score(<Font 'Candara' (Candarali.ttf) italic normal 400 normal>) = 11.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Segoe UI Symbol' (seguisym.ttf) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'OCR A Extended' (OCRAEXT.TTF) normal normal 400 expanded>) = 10.25
# 12:28:28 [DEBUG] findfont: score(<Font 'Microsoft YaHei' (msyhbd.ttc) normal normal 700 normal>) = 10.335
# 12:28:28 [DEBUG] findfont: score(<Font 'Gadugi' (gadugi.ttf) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Gabriola' (Gabriola.ttf) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Goudy Old Style' (GOUDOSB.TTF) normal normal 700 normal>) = 10.335
# 12:28:28 [DEBUG] findfont: score(<Font 'Palatino Linotype' (palab.ttf) normal normal 700 normal>) = 10.335
# 12:28:28 [DEBUG] findfont: score(<Font 'FZYaoTi' (FZYTK.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Microsoft PhagsPa' (phagspa.ttf) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'ROG Fonts v1.5' (ROG Fonts v1.5-Regular.otf) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Wingdings 2' (WINGDNG2.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Impact' (impact.ttf) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Bahnschrift' (bahnschrift.ttf) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'STXinwei' (STXINWEI.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Californian FB' (CALIFI.TTF) italic normal 400 normal>) = 11.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Lucida Bright' (LBRITEI.TTF) italic normal 400 normal>) = 11.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Viner Hand ITC' (VINERITC.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Courier New' (courbi.ttf) italic normal 700 normal>) = 11.335
# 12:28:28 [DEBUG] findfont: score(<Font 'Calisto MT' (CALIST.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Bodoni MT' (BOD_PSTC.TTF) normal normal 300 normal>) = 10.145
# 12:28:28 [DEBUG] findfont: score(<Font 'High Tower Text' (HTOWERT.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Maiandra GD' (MAIAN.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Arial' (ARIALNB.TTF) normal normal 700 condensed>) = 6.8986363636363635
# 12:28:28 [DEBUG] findfont: score(<Font 'Segoe UI Historic' (seguihis.ttf) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Bodoni MT' (BOD_CR.TTF) normal normal 400 condensed>) = 10.25
# 12:28:28 [DEBUG] findfont: score(<Font 'FangSong' (simfang.ttf) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Segoe UI' (seguili.ttf) italic normal 300 normal>) = 11.145
# 12:28:28 [DEBUG] findfont: score(<Font 'Comic Sans MS' (comic.ttf) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Tw Cen MT' (TCB_____.TTF) normal normal 700 normal>) = 10.335
# 12:28:28 [DEBUG] findfont: score(<Font 'Palatino Linotype' (palabi.ttf) italic normal 700 normal>) = 11.335
# 12:28:28 [DEBUG] findfont: score(<Font 'Segoe UI Historic' (seguihis.ttf) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Cambria' (cambriaz.ttf) italic normal 700 normal>) = 11.335
# 12:28:28 [DEBUG] findfont: score(<Font 'Lucida Bright' (LBRITE.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Lucida Console' (lucon.ttf) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Britannic Bold' (BRITANIC.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Californian FB' (CALIFI.TTF) italic normal 400 normal>) = 11.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Lucida Bright' (LBRITED.TTF) normal normal 600 normal>) = 10.24
# 12:28:28 [DEBUG] findfont: score(<Font 'Chiller' (CHILLER.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Footlight MT Light' (FTLTLT.TTF) normal normal 300 normal>) = 10.145
# 12:28:28 [DEBUG] findfont: score(<Font 'Lucida Handwriting' (LHANDW.TTF) italic normal 400 normal>) = 11.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Candara' (Candaral.ttf) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Footlight MT Light' (FTLTLT.TTF) normal normal 300 normal>) = 10.145
# 12:28:28 [DEBUG] findfont: score(<Font 'Lucida Bright' (LBRITEI.TTF) italic normal 400 normal>) = 11.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Bodoni MT' (BOD_CBI.TTF) italic normal 700 condensed>) = 11.535
# 12:28:28 [DEBUG] findfont: score(<Font 'Dubai' (DUBAI-REGULAR.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'MingLiU-ExtB' (mingliub.ttc) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Wide Latin' (LATINWD.TTF) normal normal 400 expanded>) = 10.25
# 12:28:28 [DEBUG] findfont: score(<Font 'Bernard MT Condensed' (BERNHC.TTF) normal normal 400 condensed>) = 10.25
# 12:28:28 [DEBUG] findfont: score(<Font 'Perpetua Titling MT' (PERTIBD.TTF) normal normal 700 normal>) = 10.335
# 12:28:28 [DEBUG] findfont: score(<Font 'Freestyle Script' (FREESCPT.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Bauhaus 93' (BAUHS93.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Bodoni MT' (BOD_CR.TTF) normal normal 400 condensed>) = 10.25
# 12:28:28 [DEBUG] findfont: score(<Font 'Gill Sans MT' (GILI____.TTF) italic normal 400 normal>) = 11.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Century' (CENTURY.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Nirmala UI' (NirmalaB.ttf) normal normal 700 normal>) = 10.335
# 12:28:28 [DEBUG] findfont: score(<Font 'MS Reference Sans Serif' (REFSAN.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Californian FB' (CALIFB.TTF) normal normal 700 normal>) = 10.335
# 12:28:28 [DEBUG] findfont: score(<Font 'Courier New' (couri.ttf) italic normal 400 normal>) = 11.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Myanmar Text' (mmrtext.ttf) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Microsoft Tai Le' (taileb.ttf) normal normal 700 normal>) = 10.335
# 12:28:28 [DEBUG] findfont: score(<Font 'Eras Bold ITC' (ERASBD.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Segoe UI' (segoeuiz.ttf) italic normal 700 normal>) = 11.335
# 12:28:28 [DEBUG] findfont: score(<Font 'Book Antiqua' (ANTQUABI.TTF) italic normal 700 normal>) = 11.335
# 12:28:28 [DEBUG] findfont: score(<Font 'Parchment' (PARCHM.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Bodoni MT' (BOD_I.TTF) italic normal 400 normal>) = 11.05
# 12:28:28 [DEBUG] findfont: score(<Font 'STSong' (STSONG.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Ebrima' (ebrimabd.ttf) normal normal 700 normal>) = 10.335
# 12:28:28 [DEBUG] findfont: score(<Font 'Times New Roman' (timesbd.ttf) normal normal 700 normal>) = 10.335
# 12:28:28 [DEBUG] findfont: score(<Font 'Corbel' (corbelb.ttf) normal normal 700 normal>) = 10.335
# 12:28:28 [DEBUG] findfont: score(<Font 'Times New Roman' (timesbi.ttf) italic normal 700 normal>) = 11.335
# 12:28:28 [DEBUG] findfont: score(<Font 'DengXian' (Dengb.ttf) normal normal 700 normal>) = 10.335
# 12:28:28 [DEBUG] findfont: score(<Font 'Rockwell' (ROCKB.TTF) normal normal 700 normal>) = 10.335
# 12:28:28 [DEBUG] findfont: score(<Font 'Eras Light ITC' (ERASLGHT.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Lucida Sans' (LSANS.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Yu Gothic' (YuGothB.ttc) normal normal 700 normal>) = 10.335
# 12:28:28 [DEBUG] findfont: score(<Font 'Wide Latin' (LATINWD.TTF) normal normal 400 expanded>) = 10.25
# 12:28:28 [DEBUG] findfont: score(<Font 'Corbel' (corbell.ttf) normal normal 300 normal>) = 10.145
# 12:28:28 [DEBUG] findfont: score(<Font 'Old English Text MT' (OLDENGL.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Candara' (Candaraz.ttf) italic normal 700 normal>) = 11.335
# 12:28:28 [DEBUG] findfont: score(<Font 'Lucida Fax' (LFAXI.TTF) italic normal 400 normal>) = 11.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Mistral' (MISTRAL.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Century Gothic' (GOTHIC.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Gill Sans MT Condensed' (GILC____.TTF) normal normal 400 condensed>) = 10.25
# 12:28:28 [DEBUG] findfont: score(<Font 'Goudy Stout' (GOUDYSTO.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Microsoft JhengHei' (msjhl.ttc) normal normal 290 normal>) = 10.1545
# 12:28:28 [DEBUG] findfont: score(<Font 'Palatino Linotype' (pala.ttf) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Lucida Sans Typewriter' (LTYPEO.TTF) oblique normal 400 normal>) = 11.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Microsoft Sans Serif' (micross.ttf) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Impact' (impact.ttf) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Adobe Devanagari' (AdobeDevanagari-Italic.otf) italic normal 400 normal>) = 11.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Nirmala UI' (Nirmala.ttf) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Gill Sans MT Ext Condensed Bold' (GLSNECB.TTF) normal normal 400 condensed>) = 10.25
# 12:28:28 [DEBUG] findfont: score(<Font 'Rockwell Extra Bold' (ROCKEB.TTF) normal normal 800 normal>) = 10.43
# 12:28:28 [DEBUG] findfont: score(<Font 'Gigi' (GIGI.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Goudy Old Style' (GOUDOS.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Calisto MT' (CALISTI.TTF) italic normal 400 normal>) = 11.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Segoe UI' (segoeuiz.ttf) italic normal 700 normal>) = 11.335
# 12:28:28 [DEBUG] findfont: score(<Font 'Bell MT' (BELLI.TTF) italic normal 400 normal>) = 11.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Palatino Linotype' (palabi.ttf) italic normal 700 normal>) = 11.335
# 12:28:28 [DEBUG] findfont: score(<Font 'Tw Cen MT' (TCB_____.TTF) normal normal 700 normal>) = 10.335
# 12:28:28 [DEBUG] findfont: score(<Font 'Eras Demi ITC' (ERASDEMI.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Leelawadee UI' (LeelUIsl.ttf) normal normal 350 normal>) = 10.0975
# 12:28:28 [DEBUG] findfont: score(<Font 'Segoe UI' (seguisbi.ttf) italic normal 600 normal>) = 11.24
# 12:28:28 [DEBUG] findfont: score(<Font 'MS Reference Sans Serif' (REFSAN.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Corbel' (corbeli.ttf) italic normal 400 normal>) = 11.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Tahoma' (tahomabd.ttf) normal normal 700 normal>) = 10.335
# 12:28:28 [DEBUG] findfont: score(<Font 'Harrington' (HARNGTON.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'STXinwei' (STXINWEI.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Constantia' (constani.ttf) italic normal 400 normal>) = 11.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Niagara Engraved' (NIAGENG.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'STFangsong' (STFANGSO.TTF) normal normal 400 normal>) = 10.05
# 12:28:28 [DEBUG] findfont: score(<Font 'Bodoni MT' (BOD_PSTC.TTF) normal normal 300 normal>) = 10.145
# 12:28:28 [DEBUG] findfont: Matching sans\-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0 to DejaVu Sans ('C:\\Users\\voidwu\\Anaconda3\\envs\\drl-py39\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans.ttf') with score of 0.050000.
