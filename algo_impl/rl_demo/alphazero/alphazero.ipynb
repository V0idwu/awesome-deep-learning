# %%
#!/usr/bin python3
# -*- coding: utf-8 -*-
"""
@Time    :   2022/04/07 18:25:54
@Author  :   Tianyi Wu 
@Contact :   wutianyitower@hotmail.com
@File    :   alphazero.ipynb
@Version :   1.0
@Desc    :   None
"""

# here put the import lib
import collections
import math
import logging
import sys
import numpy as np

np.random.seed(0)
import pandas as pd
import gym
import torch

torch.manual_seed(0)
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import boardgame2
from boardgame2 import BLACK, WHITE
from gym.envs.registration import register

register(id="TicTacToe-v0", entry_point="boardgame2:BoardGameEnv")

logging.basicConfig(
    level=logging.DEBUG, format="%(asctime)s [%(levelname)s] %(message)s", stream=sys.stdout, datefmt="%H:%M:%S"
)

# %%
env = gym.make(id='TicTacToe-v0', board_shape=3)
env.seed(0)
for key in vars(env):
    logging.info('%s: %s', key, vars(env)[key])
for key in vars(env.spec):
    logging.info('%s: %s', key, vars(env.spec)[key])
# Out:
# 14:14:25 [INFO] env: <BoardGameEnv<TicTacToe-v0>>
# 14:14:25 [INFO] _action_space: None
# 14:14:25 [INFO] _observation_space: None
# 14:14:25 [INFO] _reward_range: None
# 14:14:25 [INFO] _metadata: None
# 14:14:25 [INFO] _has_reset: False
# 14:14:25 [INFO] entry_point: boardgame2:BoardGameEnv
# 14:14:25 [INFO] reward_threshold: None
# 14:14:25 [INFO] nondeterministic: False
# 14:14:25 [INFO] max_episode_steps: None
# 14:14:25 [INFO] order_enforce: True
# 14:14:25 [INFO] kwargs: {'board_shape': 3}
# 14:14:25 [INFO] namespace: None
# 14:14:25 [INFO] name: TicTacToe
# 14:14:25 [INFO] version: 0

# %%
class AlphaZeroReplayer:
    def __init__(self):
        self.fields = ['player', 'board', 'prob', 'winner']
        self.memory = pd.DataFrame(columns=self.fields)

    def store(self, df):
        self.memory = pd.concat([self.memory, df[self.fields]], ignore_index=True)

    def sample(self, size):
        indices = np.random.choice(self.memory.shape[0], size=size)
        return (np.stack(self.memory.loc[indices, field]) for field in
                self.fields)

# %%
class AlphaZeroNet(nn.Module):
    def __init__(self, input_shape):
        super().__init__()

        self.input_shape = input_shape

        # common net
        self.input_net = nn.Sequential(
                nn.Conv2d(1, 256, kernel_size=3, padding="same"),
                nn.BatchNorm2d(256), nn.ReLU())
        self.residual_nets = [nn.Sequential(
                nn.Conv2d(256, 256, kernel_size=3, padding="same"),
                nn.BatchNorm2d(256)) for _ in range(2)]

        # probability net
        self.prob_net = nn.Sequential(
                nn.Conv2d(256, 256, kernel_size=3, padding="same"),
                nn.BatchNorm2d(256), nn.ReLU(),
                nn.Conv2d(256, 1, kernel_size=3, padding="same"))

        # value net
        self.value_net0 = nn.Sequential(
                nn.Conv2d(256, 1, kernel_size=3, padding="same"),
                nn.BatchNorm2d(1), nn.ReLU())
        self.value_net1 = nn.Sequential(
                nn.Linear(np.prod(input_shape), 1), nn.Tanh())


    def forward(self, board_tensor):
        # common net
        input_tensor = board_tensor.view(-1, 1, *self.input_shape)
        x = self.input_net(input_tensor)
        for i_net, residual_net in enumerate(self.residual_nets):
            y = residual_net(x)
            if i_net == len(self.residual_nets) - 1:
                y = y + x
            x = torch.clamp(y, 0)
        common_feature_tensor = x

        # probability net
        logit_tensor = self.prob_net(common_feature_tensor)
        logit_flatten_tensor = logit_tensor.view(-1)
        prob_flatten_tensor = F.softmax(logit_flatten_tensor, dim=-1)
        prob_tensor = prob_flatten_tensor.view(-1, *self.input_shape)

        # value net
        v_feature_tensor = self.value_net0(common_feature_tensor)
        v_flatten_tensor = v_feature_tensor.view(-1, np.prod(self.input_shape))
        v_tensor = self.value_net1(v_flatten_tensor)

        return prob_tensor, v_tensor

# %%
class AlphaZeroAgent:
    def __init__(self, env):
        self.env = env
        self.board = np.zeros_like(env.board)
        self.reset_mcts()

        self.replayer = AlphaZeroReplayer()

        self.net = AlphaZeroNet(input_shape=self.board.shape)
        self.prob_loss = nn.BCELoss()
        self.v_loss = nn.MSELoss()
        self.optimizer = optim.Adam(self.net.parameters(), 1e-3,
                weight_decay=1e-4)


    def reset_mcts(self):
        def zero_board_factory(): # for construct default_dict
            return np.zeros_like(self.board, dtype=float)
        self.q = collections.defaultdict(zero_board_factory)
            # q estimates: board -> board
        self.count = collections.defaultdict(zero_board_factory)
            # q count visitation: board -> board
        self.policy = {} # policy: board -> board
        self.valid = {} # valid position: board -> board
        self.winner = {} # winner: board -> None or int

    def reset(self, mode):
        self.mode = mode
        if mode == "train":
            self.trajectory = []

    def step(self, observation, winner, _):
        board, player = observation
        canonical_board = player * board
        s = boardgame2.strfboard(canonical_board)
        while self.count[s].sum() < 200: # conduct MCTS 200 times
            self.search(canonical_board, prior_noise=True)
        prob = self.count[s] / self.count[s].sum()

        # sample
        location_index = np.random.choice(prob.size, p=prob.reshape(-1))
        action = np.unravel_index(location_index, prob.shape)

        if self.mode == 'train':
            self.trajectory += [player, board, prob, winner]
        return action

    def close(self):
        if self.mode == 'train':
            self.save_trajectory_to_replayer()
            if len(self.replayer.memory) >= 1000:
                for batch in range(2): # learn multiple times
                    self.learn()
                self.replayer = AlphaZeroReplayer() # reset replayer after the agent changes itself
                self.reset_mcts()

    def save_trajectory_to_replayer(self):
        df = pd.DataFrame(
                np.array(self.trajectory, dtype=object).reshape(-1, 4),
                columns=['player', 'board', 'prob', 'winner'], dtype=object)
        winner = self.trajectory[-1]
        df['winner'] = winner
        self.replayer.store(df)

    def search(self, board, prior_noise=False): # MCTS
        s = boardgame2.strfboard(board)

        if s not in self.winner:
            self.winner[s] = self.env.get_winner((board, BLACK))
        if self.winner[s] is not None: # if there is a winner
            return self.winner[s]

        if s not in self.policy: # leaf that has not calculate the policy
            board_tensor = torch.as_tensor(board, dtype=torch.float).view(1, 1,
                    *self.board.shape)
            pi_tensor, v_tensor = self.net(board_tensor)
            pi = pi_tensor.detach().numpy()[0]
            v = v_tensor.detach().numpy()[0]
            valid = self.env.get_valid((board, BLACK))
            masked_pi = pi * valid
            total_masked_pi = np.sum(masked_pi)
            if total_masked_pi <= 0:
                # all valid actions do not have probabilities. rarely occur
                masked_pi = valid # workaround
                total_masked_pi = np.sum(masked_pi)
            self.policy[s] = masked_pi / total_masked_pi
            self.valid[s] = valid
            return v

        # calculate PUCT
        count_sum = self.count[s].sum()
        c_init = 1.25
        c_base = 19652.
        coef = (c_init + np.log1p((1 + count_sum) / c_base)) * \
                math.sqrt(count_sum) / (1. + self.count[s])
        if prior_noise:
            alpha = 1. / self.valid[s].sum()
            noise = np.random.gamma(alpha, 1., board.shape)
            noise *= self.valid[s]
            noise /= noise.sum()
            prior_exploration_fraction=0.25
            prior = (1. - prior_exploration_fraction) * self.policy[s] \
                    + prior_exploration_fraction * noise
        else:
            prior = self.policy[s]
        ub = np.where(self.valid[s], self.q[s] + coef * prior, np.nan)
        location_index = np.nanargmax(ub)
        location = np.unravel_index(location_index, board.shape)

        (next_board, next_player), _, _, _ = self.env.next_step(
                (board, BLACK), np.array(location))
        next_canonical_board = next_player * next_board
        next_v = self.search(next_canonical_board) # recursive
        v = next_player * next_v

        self.count[s][location] += 1
        self.q[s][location] += (v - self.q[s][location]) / \
                self.count[s][location]
        return v

    def learn(self):
        players, boards, probs, winners = self.replayer.sample(64)
        canonical_boards = players[:, np.newaxis, np.newaxis] * boards
        targets = (players * winners)[:, np.newaxis]

        target_prob_tensor = torch.as_tensor(probs, dtype=torch.float)
        canonical_board_tensor = torch.as_tensor(canonical_boards, dtype=torch.float)
        target_tensor = torch.as_tensor(targets, dtype=torch.float)

        prob_tensor, v_tensor = self.net(canonical_board_tensor)

        flatten_target_prob_tensor = target_prob_tensor.view(-1, self.board.size)
        flatten_prob_tensor = prob_tensor.view(-1, self.board.size)
        prob_loss_tensor = self.prob_loss(flatten_prob_tensor,
                flatten_target_prob_tensor)
        v_loss_tensor = self.v_loss(v_tensor, target_tensor)
        loss_tensor = prob_loss_tensor + v_loss_tensor
        self.optimizer.zero_grad()
        loss_tensor.backward()
        self.optimizer.step()


agent = AlphaZeroAgent(env=env)

# %%
def play_boardgame2_episode(env, agent, mode=None, verbose=False):
    observation, winner, done = env.reset(), 0, False
    agent.reset(mode=mode)
    elapsed_steps = 0
    while True:
        if verbose:
            board, player = observation
            print(boardgame2.strfboard(board))
        action = agent.step(observation, winner, done)
        if verbose:
            logging.info('step %d：player %d, action %s', elapsed_steps, player,
                    action)
        observation, winner, done, _ = env.step(action)
        if done:
            if verbose:
                board, _ = observation
                print(boardgame2.strfboard(board))
            break
        elapsed_steps += 1
    agent.close()
    return winner, elapsed_steps


for episode in range(5000):
    winner, elapsed_steps = play_boardgame2_episode(env, agent, mode='train')
    logging.info('train episode %d: winner = %d, steps = %d', episode, winner,
            elapsed_steps)

    if len(agent.replayer.memory) == 0: # just finish learning
        logging.info('test episode %d:', episode)
        winner, elapsed_steps = play_boardgame2_episode(env, agent, mode='test',
                verbose=True)
        logging.info('test episode %d: winner = %d, steps = %d',
                episode, winner, elapsed_steps)
# Out:
# 14:14:30 [INFO] train episode 0: winner = 1, steps = 8
# 14:14:33 [INFO] train episode 1: winner = 1, steps = 8
# 14:14:35 [INFO] train episode 2: winner = 1, steps = 8
# 14:14:38 [INFO] train episode 3: winner = 1, steps = 8
# 14:14:40 [INFO] train episode 4: winner = 1, steps = 8
# 14:14:40 [INFO] train episode 5: winner = 1, steps = 8
# 14:14:42 [INFO] train episode 6: winner = 1, steps = 8
# 14:14:43 [INFO] train episode 7: winner = 1, steps = 8
# 14:14:43 [INFO] train episode 8: winner = 1, steps = 8
# 14:14:45 [INFO] train episode 9: winner = 1, steps = 8
# 14:14:48 [INFO] train episode 10: winner = 1, steps = 8
# 14:14:49 [INFO] train episode 11: winner = 1, steps = 8
# 14:14:51 [INFO] train episode 12: winner = 1, steps = 8
# 14:14:51 [INFO] train episode 13: winner = 1, steps = 8
# 14:14:53 [INFO] train episode 14: winner = 1, steps = 8
# 14:14:55 [INFO] train episode 15: winner = 1, steps = 8
# 14:14:55 [INFO] train episode 16: winner = 1, steps = 8
# 14:14:56 [INFO] train episode 17: winner = 1, steps = 8
# 14:14:56 [INFO] train episode 18: winner = 1, steps = 8
# 14:14:57 [INFO] train episode 19: winner = 1, steps = 8
# 14:14:58 [INFO] train episode 20: winner = 1, steps = 8
# 14:14:58 [INFO] train episode 21: winner = 1, steps = 8
# 14:14:59 [INFO] train episode 22: winner = 1, steps = 8
# 14:15:01 [INFO] train episode 23: winner = 1, steps = 8
# 14:15:02 [INFO] train episode 24: winner = 1, steps = 8
# 14:15:02 [INFO] train episode 25: winner = 1, steps = 8
# 14:15:03 [INFO] train episode 26: winner = 1, steps = 8
# 14:15:04 [INFO] train episode 27: winner = 1, steps = 8
# 14:15:05 [INFO] train episode 28: winner = 1, steps = 8
# 14:15:06 [INFO] train episode 29: winner = 1, steps = 8
# 14:15:07 [INFO] train episode 30: winner = 1, steps = 8
# 14:15:08 [INFO] train episode 31: winner = 1, steps = 8
# 14:15:08 [INFO] train episode 32: winner = 1, steps = 8
# 14:15:09 [INFO] train episode 33: winner = 1, steps = 8
# 14:15:10 [INFO] train episode 34: winner = 1, steps = 8
# 14:15:11 [INFO] train episode 35: winner = 1, steps = 8
# 14:15:11 [INFO] train episode 36: winner = 1, steps = 8
# 14:15:12 [INFO] train episode 37: winner = 1, steps = 8
# 14:15:12 [INFO] train episode 38: winner = 1, steps = 8
# 14:15:13 [INFO] train episode 39: winner = 1, steps = 8
# 14:15:14 [INFO] train episode 40: winner = 1, steps = 8
# 14:15:16 [INFO] train episode 41: winner = 1, steps = 8
# 14:15:17 [INFO] train episode 42: winner = 1, steps = 8
# 14:15:18 [INFO] train episode 43: winner = 1, steps = 8
# 14:15:19 [INFO] train episode 44: winner = 1, steps = 8
# 14:15:19 [INFO] train episode 45: winner = 1, steps = 8
# 14:15:20 [INFO] train episode 46: winner = 1, steps = 8
# 14:15:20 [INFO] train episode 47: winner = 1, steps = 8
# 14:15:21 [INFO] train episode 48: winner = 1, steps = 8
# 14:15:21 [INFO] train episode 49: winner = 1, steps = 8
# 14:15:22 [INFO] train episode 50: winner = 1, steps = 8
# 14:15:23 [INFO] train episode 51: winner = 1, steps = 8
# 14:15:24 [INFO] train episode 52: winner = 1, steps = 8
# 14:15:24 [INFO] train episode 53: winner = 1, steps = 8
# 14:15:25 [INFO] train episode 54: winner = 1, steps = 8
# 14:15:25 [INFO] train episode 55: winner = 1, steps = 8
# 14:15:26 [INFO] train episode 56: winner = 1, steps = 8
# 14:15:26 [INFO] train episode 57: winner = 1, steps = 8
# 14:15:27 [INFO] train episode 58: winner = 1, steps = 8
# 14:15:28 [INFO] train episode 59: winner = 1, steps = 8
# 14:15:28 [INFO] train episode 60: winner = 1, steps = 8
# 14:15:29 [INFO] train episode 61: winner = 1, steps = 8
# 14:15:30 [INFO] train episode 62: winner = 1, steps = 8
# 14:15:31 [INFO] train episode 63: winner = 1, steps = 8
# 14:15:32 [INFO] train episode 64: winner = 1, steps = 8
# 14:15:32 [INFO] train episode 65: winner = 1, steps = 8
# 14:15:32 [INFO] train episode 66: winner = 1, steps = 8
# 14:15:33 [INFO] train episode 67: winner = 1, steps = 8
# 14:15:34 [INFO] train episode 68: winner = 1, steps = 8
# 14:15:34 [INFO] train episode 69: winner = 1, steps = 8
# 14:15:35 [INFO] train episode 70: winner = 1, steps = 8
# 14:15:35 [INFO] train episode 71: winner = 1, steps = 8
# 14:15:35 [INFO] train episode 72: winner = 1, steps = 8
# 14:15:36 [INFO] train episode 73: winner = 1, steps = 8
# 14:15:36 [INFO] train episode 74: winner = 1, steps = 8
# 14:15:37 [INFO] train episode 75: winner = 1, steps = 8
# 14:15:37 [INFO] train episode 76: winner = 1, steps = 8
# 14:15:38 [INFO] train episode 77: winner = 1, steps = 8
# 14:15:39 [INFO] train episode 78: winner = 1, steps = 8
# 14:15:39 [INFO] train episode 79: winner = 1, steps = 8
# 14:15:40 [INFO] train episode 80: winner = 1, steps = 8
# 14:15:41 [INFO] train episode 81: winner = 1, steps = 8
# 14:15:41 [INFO] train episode 82: winner = 1, steps = 8
# 14:15:41 [INFO] train episode 83: winner = 1, steps = 8
# 14:15:41 [INFO] train episode 84: winner = 1, steps = 8
# 14:15:42 [INFO] train episode 85: winner = 1, steps = 8
# 14:15:43 [INFO] train episode 86: winner = 1, steps = 8
# 14:15:43 [INFO] train episode 87: winner = 1, steps = 8
# 14:15:44 [INFO] train episode 88: winner = 1, steps = 8
# 14:15:44 [INFO] train episode 89: winner = 1, steps = 8
# 14:15:44 [INFO] train episode 90: winner = 1, steps = 8
# 14:15:45 [INFO] train episode 91: winner = 1, steps = 8
# 14:15:46 [INFO] train episode 92: winner = 1, steps = 8
# 14:15:47 [INFO] train episode 93: winner = 1, steps = 8
# 14:15:47 [INFO] train episode 94: winner = 1, steps = 8
# 14:15:47 [INFO] train episode 95: winner = 1, steps = 8
# 14:15:48 [INFO] train episode 96: winner = 1, steps = 8
# 14:15:48 [INFO] train episode 97: winner = 1, steps = 8
# 14:15:49 [INFO] train episode 98: winner = 1, steps = 8
# 14:15:49 [INFO] train episode 99: winner = 1, steps = 8
# 14:15:49 [INFO] train episode 100: winner = 1, steps = 8
# 14:15:50 [INFO] train episode 101: winner = 1, steps = 8
# 14:15:50 [INFO] train episode 102: winner = 1, steps = 8
# 14:15:51 [INFO] train episode 103: winner = 1, steps = 8
# 14:15:52 [INFO] train episode 104: winner = 1, steps = 8
# 14:15:52 [INFO] train episode 105: winner = 1, steps = 8
# 14:15:52 [INFO] train episode 106: winner = 1, steps = 8
# 14:15:52 [INFO] train episode 107: winner = 1, steps = 8
# 14:15:53 [INFO] train episode 108: winner = 1, steps = 8
# 14:15:53 [INFO] train episode 109: winner = 1, steps = 8
# 14:15:54 [INFO] train episode 110: winner = 1, steps = 8
# 14:15:55 [INFO] train episode 111: winner = 1, steps = 8
# 14:15:55 [INFO] test episode 111:
# +++
# +++
# +++
# 14:15:56 [INFO] step 0:player 1, action (0, 1)
# +o+
# +++
# +++
# 14:15:57 [INFO] step 1:player -1, action (1, 1)
# +o+
# +x+
# +++
# 14:15:58 [INFO] step 2:player 1, action (1, 0)
# +o+
# ox+
# +++
# 14:15:59 [INFO] step 3:player -1, action (1, 2)
# +o+
# oxx
# +++
# 14:15:59 [INFO] step 4:player 1, action (2, 2)
# +o+
# oxx
# ++o
# 14:15:59 [INFO] step 5:player -1, action (0, 0)
# xo+
# oxx
# ++o
# 14:16:00 [INFO] step 6:player 1, action (0, 2)
# xoo
# oxx
# ++o
# 14:16:00 [INFO] step 7:player -1, action (2, 1)
# xoo
# oxx
# +xo
# 14:16:00 [INFO] step 8:player 1, action (2, 0)
# xoo
# oxx
# oxo
# 14:16:00 [INFO] test episode 111: winner = 1, steps = 8
# 14:16:02 [INFO] train episode 112: winner = 1, steps = 8
# 14:16:05 [INFO] train episode 113: winner = 1, steps = 8
# 14:16:08 [INFO] train episode 114: winner = 1, steps = 8
# 14:16:10 [INFO] train episode 115: winner = 1, steps = 8
# 14:16:11 [INFO] train episode 116: winner = 1, steps = 8
# 14:16:13 [INFO] train episode 117: winner = 1, steps = 8
# 14:16:14 [INFO] train episode 118: winner = 1, steps = 8
# 14:16:15 [INFO] train episode 119: winner = 1, steps = 8
# 14:16:16 [INFO] train episode 120: winner = 1, steps = 8
# 14:16:19 [INFO] train episode 121: winner = 1, steps = 8
# 14:16:19 [INFO] train episode 122: winner = 1, steps = 8
# 14:16:20 [INFO] train episode 123: winner = 1, steps = 8
# 14:16:20 [INFO] train episode 124: winner = 1, steps = 8
# 14:16:21 [INFO] train episode 125: winner = 1, steps = 8
# 14:16:23 [INFO] train episode 126: winner = 1, steps = 8
# 14:16:23 [INFO] train episode 127: winner = 1, steps = 8
# 14:16:24 [INFO] train episode 128: winner = 1, steps = 8
# 14:16:25 [INFO] train episode 129: winner = 1, steps = 8
# 14:16:26 [INFO] train episode 130: winner = 1, steps = 8
# 14:16:27 [INFO] train episode 131: winner = 1, steps = 8
# 14:16:28 [INFO] train episode 132: winner = 1, steps = 8
# 14:16:30 [INFO] train episode 133: winner = 1, steps = 8
# 14:16:31 [INFO] train episode 134: winner = 1, steps = 8
# 14:16:32 [INFO] train episode 135: winner = 1, steps = 8
# 14:16:32 [INFO] train episode 136: winner = 1, steps = 8
# 14:16:34 [INFO] train episode 137: winner = 1, steps = 8
# 14:16:35 [INFO] train episode 138: winner = 1, steps = 8
# 14:16:35 [INFO] train episode 139: winner = 1, steps = 8
# 14:16:36 [INFO] train episode 140: winner = 1, steps = 8
# 14:16:36 [INFO] train episode 141: winner = 1, steps = 8
# 14:16:37 [INFO] train episode 142: winner = 1, steps = 8
# 14:16:38 [INFO] train episode 143: winner = 1, steps = 8
# 14:16:38 [INFO] train episode 144: winner = 1, steps = 8
# 14:16:39 [INFO] train episode 145: winner = 1, steps = 8
# 14:16:40 [INFO] train episode 146: winner = 1, steps = 8
# 14:16:41 [INFO] train episode 147: winner = 1, steps = 8
# 14:16:42 [INFO] train episode 148: winner = 1, steps = 8
# 14:16:42 [INFO] train episode 149: winner = 1, steps = 8
# 14:16:42 [INFO] train episode 150: winner = 1, steps = 8
# 14:16:43 [INFO] train episode 151: winner = 1, steps = 8
# 14:16:43 [INFO] train episode 152: winner = 1, steps = 8
# 14:16:43 [INFO] train episode 153: winner = 1, steps = 8
# 14:16:44 [INFO] train episode 154: winner = 1, steps = 8
# 14:16:44 [INFO] train episode 155: winner = 1, steps = 8
# 14:16:45 [INFO] train episode 156: winner = 1, steps = 8
# 14:16:46 [INFO] train episode 157: winner = 1, steps = 8
# 14:16:47 [INFO] train episode 158: winner = 1, steps = 8
# 14:16:48 [INFO] train episode 159: winner = 1, steps = 8
# 14:16:48 [INFO] train episode 160: winner = 1, steps = 8
# 14:16:49 [INFO] train episode 161: winner = 1, steps = 8
# 14:16:50 [INFO] train episode 162: winner = 1, steps = 8
# 14:16:50 [INFO] train episode 163: winner = 1, steps = 8
# 14:16:51 [INFO] train episode 164: winner = 1, steps = 8
# 14:16:52 [INFO] train episode 165: winner = 1, steps = 8
# 14:16:53 [INFO] train episode 166: winner = 1, steps = 8
# 14:16:54 [INFO] train episode 167: winner = 1, steps = 8
# 14:16:54 [INFO] train episode 168: winner = 1, steps = 8
# 14:16:55 [INFO] train episode 169: winner = 1, steps = 8
# 14:16:55 [INFO] train episode 170: winner = 1, steps = 8
# 14:16:56 [INFO] train episode 171: winner = 1, steps = 8
# 14:16:56 [INFO] train episode 172: winner = 1, steps = 8
# 14:16:57 [INFO] train episode 173: winner = 1, steps = 8
# 14:16:57 [INFO] train episode 174: winner = 1, steps = 8
# 14:16:58 [INFO] train episode 175: winner = 1, steps = 8
# 14:16:58 [INFO] train episode 176: winner = 1, steps = 8
# 14:16:59 [INFO] train episode 177: winner = 1, steps = 8
# 14:16:59 [INFO] train episode 178: winner = 1, steps = 8
# 14:17:00 [INFO] train episode 179: winner = 1, steps = 8
# 14:17:01 [INFO] train episode 180: winner = 1, steps = 8
# 14:17:01 [INFO] train episode 181: winner = 1, steps = 8
# 14:17:02 [INFO] train episode 182: winner = 1, steps = 8
# 14:17:02 [INFO] train episode 183: winner = 1, steps = 8
# 14:17:02 [INFO] train episode 184: winner = 1, steps = 8
# 14:17:02 [INFO] train episode 185: winner = 1, steps = 8
# 14:17:03 [INFO] train episode 186: winner = 1, steps = 8
# 14:17:04 [INFO] train episode 187: winner = 1, steps = 8
# 14:17:04 [INFO] train episode 188: winner = 1, steps = 8
# 14:17:05 [INFO] train episode 189: winner = 1, steps = 8
# 14:17:06 [INFO] train episode 190: winner = 1, steps = 8
# 14:17:06 [INFO] train episode 191: winner = 1, steps = 8
# 14:17:07 [INFO] train episode 192: winner = 1, steps = 8
# 14:17:08 [INFO] train episode 193: winner = 1, steps = 8
# 14:17:08 [INFO] train episode 194: winner = 1, steps = 8
# 14:17:08 [INFO] train episode 195: winner = 1, steps = 8
# 14:17:09 [INFO] train episode 196: winner = 1, steps = 8
# 14:17:09 [INFO] train episode 197: winner = 1, steps = 8
# 14:17:10 [INFO] train episode 198: winner = 1, steps = 8
# 14:17:10 [INFO] train episode 199: winner = 1, steps = 8
# 14:17:11 [INFO] train episode 200: winner = 1, steps = 8
# 14:17:12 [INFO] train episode 201: winner = 1, steps = 8
# 14:17:12 [INFO] train episode 202: winner = 1, steps = 8
# 14:17:13 [INFO] train episode 203: winner = 1, steps = 8
# 14:17:13 [INFO] train episode 204: winner = 1, steps = 8
# 14:17:14 [INFO] train episode 205: winner = 1, steps = 8
# 14:17:14 [INFO] train episode 206: winner = 1, steps = 8
# 14:17:15 [INFO] train episode 207: winner = 1, steps = 8
# 14:17:15 [INFO] train episode 208: winner = 1, steps = 8
# 14:17:15 [INFO] train episode 209: winner = 1, steps = 8
# 14:17:16 [INFO] train episode 210: winner = 1, steps = 8
# 14:17:16 [INFO] train episode 211: winner = 1, steps = 8
# 14:17:17 [INFO] train episode 212: winner = 1, steps = 8
# 14:17:17 [INFO] train episode 213: winner = 1, steps = 8
# 14:17:18 [INFO] train episode 214: winner = 1, steps = 8
# 14:17:18 [INFO] train episode 215: winner = 1, steps = 8
# 14:17:19 [INFO] train episode 216: winner = 1, steps = 8
# 14:17:19 [INFO] train episode 217: winner = 1, steps = 8
# 14:17:19 [INFO] train episode 218: winner = 1, steps = 8
# 14:17:20 [INFO] train episode 219: winner = 1, steps = 8
# 14:17:21 [INFO] train episode 220: winner = 1, steps = 8
# 14:17:22 [INFO] train episode 221: winner = 1, steps = 8
# 14:17:22 [INFO] train episode 222: winner = 1, steps = 8
# 14:17:22 [INFO] train episode 223: winner = 1, steps = 8
# 14:17:22 [INFO] test episode 223:
# +++
# +++
# +++
# 14:17:24 [INFO] step 0:player 1, action (1, 0)
# +++
# o++
# +++
# 14:17:25 [INFO] step 1:player -1, action (0, 2)
# ++x
# o++
# +++
# 14:17:26 [INFO] step 2:player 1, action (0, 1)
# +ox
# o++
# +++
# 14:17:26 [INFO] step 3:player -1, action (1, 2)
# +ox
# o+x
# +++
# 14:17:27 [INFO] step 4:player 1, action (2, 0)
# +ox
# o+x
# o++
# 14:17:27 [INFO] step 5:player -1, action (1, 1)
# +ox
# oxx
# o++
# 14:17:27 [INFO] step 6:player 1, action (0, 0)
# oox
# oxx
# o++
# 14:17:27 [INFO] step 7:player -1, action (2, 2)
# oox
# oxx
# o+x
# 14:17:27 [INFO] step 8:player 1, action (2, 1)
# oox
# oxx
# oox
# 14:17:27 [INFO] test episode 223: winner = 1, steps = 8
# 14:17:30 [INFO] train episode 224: winner = 1, steps = 8
# 14:17:33 [INFO] train episode 225: winner = 1, steps = 8
# 14:17:34 [INFO] train episode 226: winner = 1, steps = 8
# 14:17:35 [INFO] train episode 227: winner = 1, steps = 8
# 14:17:36 [INFO] train episode 228: winner = 1, steps = 8
# 14:17:37 [INFO] train episode 229: winner = 1, steps = 8
# 14:17:39 [INFO] train episode 230: winner = 1, steps = 8
# 14:17:43 [INFO] train episode 231: winner = 1, steps = 8
# 14:17:46 [INFO] train episode 232: winner = 1, steps = 8
# 14:17:47 [INFO] train episode 233: winner = 1, steps = 8
# 14:17:49 [INFO] train episode 234: winner = 1, steps = 8
# 14:17:51 [INFO] train episode 235: winner = 1, steps = 8
# 14:17:53 [INFO] train episode 236: winner = 1, steps = 8
# 14:17:53 [INFO] train episode 237: winner = 1, steps = 8
# 14:17:55 [INFO] train episode 238: winner = 1, steps = 8
# 14:17:56 [INFO] train episode 239: winner = 1, steps = 8
# 14:17:57 [INFO] train episode 240: winner = 1, steps = 8
# 14:17:59 [INFO] train episode 241: winner = 1, steps = 8
# 14:18:01 [INFO] train episode 242: winner = 1, steps = 8
# 14:18:01 [INFO] train episode 243: winner = 1, steps = 8
# 14:18:03 [INFO] train episode 244: winner = 1, steps = 8
# 14:18:04 [INFO] train episode 245: winner = 1, steps = 8
# 14:18:05 [INFO] train episode 246: winner = 1, steps = 8
# 14:18:05 [INFO] train episode 247: winner = 1, steps = 8
# 14:18:07 [INFO] train episode 248: winner = 1, steps = 8
# 14:18:07 [INFO] train episode 249: winner = 1, steps = 8
# 14:18:08 [INFO] train episode 250: winner = 1, steps = 8
# 14:18:08 [INFO] train episode 251: winner = 1, steps = 8
# 14:18:09 [INFO] train episode 252: winner = 1, steps = 8
# 14:18:10 [INFO] train episode 253: winner = 1, steps = 8
# 14:18:12 [INFO] train episode 254: winner = 1, steps = 8
# 14:18:13 [INFO] train episode 255: winner = 1, steps = 8
# 14:18:13 [INFO] train episode 256: winner = 1, steps = 8
# 14:18:15 [INFO] train episode 257: winner = 1, steps = 8
# 14:18:16 [INFO] train episode 258: winner = 1, steps = 8
# 14:18:16 [INFO] train episode 259: winner = 1, steps = 8
# 14:18:17 [INFO] train episode 260: winner = 1, steps = 8
# 14:18:18 [INFO] train episode 261: winner = 1, steps = 8
# 14:18:18 [INFO] train episode 262: winner = 1, steps = 8
# 14:18:20 [INFO] train episode 263: winner = 1, steps = 8
# 14:18:20 [INFO] train episode 264: winner = 1, steps = 8
# 14:18:21 [INFO] train episode 265: winner = 1, steps = 8
# 14:18:22 [INFO] train episode 266: winner = 1, steps = 8
# 14:18:22 [INFO] train episode 267: winner = 1, steps = 8
# 14:18:23 [INFO] train episode 268: winner = 1, steps = 8
# 14:18:24 [INFO] train episode 269: winner = 1, steps = 8
# 14:18:25 [INFO] train episode 270: winner = 1, steps = 8
# 14:18:26 [INFO] train episode 271: winner = 1, steps = 8
# 14:18:26 [INFO] train episode 272: winner = 1, steps = 8
# 14:18:27 [INFO] train episode 273: winner = 1, steps = 8
# 14:18:28 [INFO] train episode 274: winner = 1, steps = 8
# 14:18:28 [INFO] train episode 275: winner = 1, steps = 8
# 14:18:29 [INFO] train episode 276: winner = 1, steps = 8
# 14:18:29 [INFO] train episode 277: winner = 1, steps = 8
# 14:18:30 [INFO] train episode 278: winner = 1, steps = 8
# 14:18:30 [INFO] train episode 279: winner = 1, steps = 8
# 14:18:31 [INFO] train episode 280: winner = 1, steps = 8
# 14:18:32 [INFO] train episode 281: winner = 1, steps = 8
# 14:18:33 [INFO] train episode 282: winner = 1, steps = 8
# 14:18:34 [INFO] train episode 283: winner = 1, steps = 8
# 14:18:34 [INFO] train episode 284: winner = 1, steps = 8
# 14:18:34 [INFO] train episode 285: winner = 1, steps = 8
# 14:18:35 [INFO] train episode 286: winner = 1, steps = 8
# 14:18:36 [INFO] train episode 287: winner = 1, steps = 8
# 14:18:37 [INFO] train episode 288: winner = 1, steps = 8
# 14:18:38 [INFO] train episode 289: winner = 1, steps = 8
# 14:18:38 [INFO] train episode 290: winner = 1, steps = 8
# 14:18:39 [INFO] train episode 291: winner = 1, steps = 8
# 14:18:39 [INFO] train episode 292: winner = 1, steps = 8
# 14:18:40 [INFO] train episode 293: winner = 1, steps = 8
# 14:18:41 [INFO] train episode 294: winner = 1, steps = 8
# 14:18:41 [INFO] train episode 295: winner = 1, steps = 8
# 14:18:42 [INFO] train episode 296: winner = 1, steps = 8
# 14:18:42 [INFO] train episode 297: winner = 1, steps = 8
# 14:18:43 [INFO] train episode 298: winner = 1, steps = 8
# 14:18:43 [INFO] train episode 299: winner = 1, steps = 8
# 14:18:44 [INFO] train episode 300: winner = 1, steps = 8
# 14:18:45 [INFO] train episode 301: winner = 1, steps = 8
# 14:18:46 [INFO] train episode 302: winner = 1, steps = 8
# 14:18:47 [INFO] train episode 303: winner = 1, steps = 8
# 14:18:47 [INFO] train episode 304: winner = 1, steps = 8
# 14:18:48 [INFO] train episode 305: winner = 1, steps = 8
# 14:18:49 [INFO] train episode 306: winner = 1, steps = 8
# 14:18:49 [INFO] train episode 307: winner = 1, steps = 8
# 14:18:49 [INFO] train episode 308: winner = 1, steps = 8
# 14:18:50 [INFO] train episode 309: winner = 1, steps = 8
# 14:18:51 [INFO] train episode 310: winner = 1, steps = 8
# 14:18:51 [INFO] train episode 311: winner = 1, steps = 8
# 14:18:51 [INFO] train episode 312: winner = 1, steps = 8
# 14:18:52 [INFO] train episode 313: winner = 1, steps = 8
# 14:18:53 [INFO] train episode 314: winner = 1, steps = 8
# 14:18:53 [INFO] train episode 315: winner = 1, steps = 8
# 14:18:53 [INFO] train episode 316: winner = 1, steps = 8
# 14:18:54 [INFO] train episode 317: winner = 1, steps = 8
# 14:18:55 [INFO] train episode 318: winner = 1, steps = 8
# 14:18:55 [INFO] train episode 319: winner = 1, steps = 8
# 14:18:56 [INFO] train episode 320: winner = 1, steps = 8
# 14:18:57 [INFO] train episode 321: winner = 1, steps = 8
# 14:18:58 [INFO] train episode 322: winner = 1, steps = 8
# 14:18:58 [INFO] train episode 323: winner = 1, steps = 8
# 14:18:58 [INFO] train episode 324: winner = 1, steps = 8
# 14:18:58 [INFO] train episode 325: winner = 1, steps = 8
# 14:18:59 [INFO] train episode 326: winner = 1, steps = 8
# 14:19:00 [INFO] train episode 327: winner = 1, steps = 8
# 14:19:01 [INFO] train episode 328: winner = 1, steps = 8
# 14:19:01 [INFO] train episode 329: winner = 1, steps = 8
# 14:19:02 [INFO] train episode 330: winner = 1, steps = 8
# 14:19:02 [INFO] train episode 331: winner = 1, steps = 8
# 14:19:03 [INFO] train episode 332: winner = 1, steps = 8
# 14:19:03 [INFO] train episode 333: winner = 1, steps = 8
# 14:19:04 [INFO] train episode 334: winner = 1, steps = 8
# 14:19:04 [INFO] train episode 335: winner = 1, steps = 8
# 14:19:04 [INFO] test episode 335:
# +++
# +++
# +++
# 14:19:05 [INFO] step 0:player 1, action (1, 1)
# +++
# +o+
# +++
# 14:19:07 [INFO] step 1:player -1, action (0, 1)
# +x+
# +o+
# +++
# 14:19:08 [INFO] step 2:player 1, action (0, 0)
# ox+
# +o+
# +++
# 14:19:09 [INFO] step 3:player -1, action (1, 0)
# ox+
# xo+
# +++
# 14:19:09 [INFO] step 4:player 1, action (2, 1)
# ox+
# xo+
# +o+
# 14:19:09 [INFO] step 5:player -1, action (2, 2)
# ox+
# xo+
# +ox
# 14:19:09 [INFO] step 6:player 1, action (0, 2)
# oxo
# xo+
# +ox
# 14:19:09 [INFO] step 7:player -1, action (2, 0)
# oxo
# xo+
# xox
# 14:19:09 [INFO] step 8:player 1, action (1, 2)
# oxo
# xoo
# xox
# 14:19:09 [INFO] test episode 335: winner = 1, steps = 8
# 14:19:12 [INFO] train episode 336: winner = 1, steps = 8
# 14:19:13 [INFO] train episode 337: winner = 1, steps = 8
# 14:19:17 [INFO] train episode 338: winner = 1, steps = 8
# 14:19:19 [INFO] train episode 339: winner = 1, steps = 8
# 14:19:22 [INFO] train episode 340: winner = 1, steps = 8
# 14:19:24 [INFO] train episode 341: winner = 1, steps = 8
# 14:19:26 [INFO] train episode 342: winner = 1, steps = 8
# 14:19:26 [INFO] train episode 343: winner = 1, steps = 8
# 14:19:28 [INFO] train episode 344: winner = 1, steps = 8
# 14:19:28 [INFO] train episode 345: winner = 1, steps = 8
# 14:19:31 [INFO] train episode 346: winner = 1, steps = 8
# 14:19:31 [INFO] train episode 347: winner = 1, steps = 8
# 14:19:33 [INFO] train episode 348: winner = 1, steps = 8
# 14:19:33 [INFO] train episode 349: winner = 1, steps = 8
# 14:19:34 [INFO] train episode 350: winner = 1, steps = 8
# 14:19:35 [INFO] train episode 351: winner = 1, steps = 8
# 14:19:36 [INFO] train episode 352: winner = 1, steps = 8
# 14:19:38 [INFO] train episode 353: winner = 1, steps = 8
# 14:19:39 [INFO] train episode 354: winner = 1, steps = 8
# 14:19:40 [INFO] train episode 355: winner = 1, steps = 8
# 14:19:41 [INFO] train episode 356: winner = 1, steps = 8
# 14:19:42 [INFO] train episode 357: winner = 1, steps = 8
# 14:19:44 [INFO] train episode 358: winner = 1, steps = 8
# 14:19:45 [INFO] train episode 359: winner = 1, steps = 8
# 14:19:46 [INFO] train episode 360: winner = 1, steps = 8
# 14:19:47 [INFO] train episode 361: winner = 1, steps = 8
# 14:19:48 [INFO] train episode 362: winner = 1, steps = 8
# 14:19:50 [INFO] train episode 363: winner = 1, steps = 8
# 14:19:52 [INFO] train episode 364: winner = 1, steps = 8
# 14:19:53 [INFO] train episode 365: winner = 1, steps = 8
# 14:19:54 [INFO] train episode 366: winner = 1, steps = 8
# 14:19:54 [INFO] train episode 367: winner = 1, steps = 8
# 14:19:55 [INFO] train episode 368: winner = 1, steps = 8
# 14:19:56 [INFO] train episode 369: winner = 1, steps = 8
# 14:19:57 [INFO] train episode 370: winner = 1, steps = 8
# 14:19:57 [INFO] train episode 371: winner = 1, steps = 8
# 14:19:58 [INFO] train episode 372: winner = 1, steps = 8
# 14:19:59 [INFO] train episode 373: winner = 1, steps = 8
# 14:20:00 [INFO] train episode 374: winner = 1, steps = 8
# 14:20:00 [INFO] train episode 375: winner = 1, steps = 8
# 14:20:01 [INFO] train episode 376: winner = 1, steps = 8
# 14:20:02 [INFO] train episode 377: winner = 1, steps = 8
# 14:20:03 [INFO] train episode 378: winner = 1, steps = 8
# 14:20:04 [INFO] train episode 379: winner = 1, steps = 8
# 14:20:05 [INFO] train episode 380: winner = 1, steps = 8
# 14:20:05 [INFO] train episode 381: winner = 1, steps = 8
# 14:20:06 [INFO] train episode 382: winner = 1, steps = 8
# 14:20:07 [INFO] train episode 383: winner = 1, steps = 8
# 14:20:07 [INFO] train episode 384: winner = 1, steps = 8
# 14:20:08 [INFO] train episode 385: winner = 1, steps = 8
# 14:20:09 [INFO] train episode 386: winner = 1, steps = 8
# 14:20:09 [INFO] train episode 387: winner = 1, steps = 8
# 14:20:10 [INFO] train episode 388: winner = 1, steps = 8
# 14:20:10 [INFO] train episode 389: winner = 1, steps = 8
# 14:20:10 [INFO] train episode 390: winner = 1, steps = 8
# 14:20:11 [INFO] train episode 391: winner = 1, steps = 8
# 14:20:12 [INFO] train episode 392: winner = 1, steps = 8
# 14:20:12 [INFO] train episode 393: winner = 1, steps = 8
# 14:20:13 [INFO] train episode 394: winner = 1, steps = 8
# 14:20:13 [INFO] train episode 395: winner = 1, steps = 8
# 14:20:13 [INFO] train episode 396: winner = 1, steps = 8
# 14:20:14 [INFO] train episode 397: winner = 1, steps = 8
# 14:20:15 [INFO] train episode 398: winner = 1, steps = 8
# 14:20:15 [INFO] train episode 399: winner = 1, steps = 8
# 14:20:16 [INFO] train episode 400: winner = 1, steps = 8
# 14:20:16 [INFO] train episode 401: winner = 1, steps = 8
# 14:20:17 [INFO] train episode 402: winner = 1, steps = 8
# 14:20:18 [INFO] train episode 403: winner = 1, steps = 8
# 14:20:18 [INFO] train episode 404: winner = 1, steps = 8
# 14:20:19 [INFO] train episode 405: winner = 1, steps = 8
# 14:20:19 [INFO] train episode 406: winner = 1, steps = 8
# 14:20:20 [INFO] train episode 407: winner = 1, steps = 8
# 14:20:21 [INFO] train episode 408: winner = 1, steps = 8
# 14:20:22 [INFO] train episode 409: winner = 1, steps = 8
# 14:20:23 [INFO] train episode 410: winner = 1, steps = 8
# 14:20:23 [INFO] train episode 411: winner = 1, steps = 8
# 14:20:24 [INFO] train episode 412: winner = 1, steps = 8
# 14:20:24 [INFO] train episode 413: winner = 1, steps = 8
# 14:20:25 [INFO] train episode 414: winner = 1, steps = 8
# 14:20:25 [INFO] train episode 415: winner = 1, steps = 8
# 14:20:26 [INFO] train episode 416: winner = 1, steps = 8
# 14:20:26 [INFO] train episode 417: winner = 1, steps = 8
# 14:20:27 [INFO] train episode 418: winner = 1, steps = 8
# 14:20:27 [INFO] train episode 419: winner = 1, steps = 8
# 14:20:28 [INFO] train episode 420: winner = 1, steps = 8
# 14:20:28 [INFO] train episode 421: winner = 1, steps = 8
# 14:20:29 [INFO] train episode 422: winner = 1, steps = 8
# 14:20:30 [INFO] train episode 423: winner = 1, steps = 8
# 14:20:31 [INFO] train episode 424: winner = 1, steps = 8
# 14:20:32 [INFO] train episode 425: winner = 1, steps = 8
# 14:20:32 [INFO] train episode 426: winner = 1, steps = 8
# 14:20:32 [INFO] train episode 427: winner = 1, steps = 8
# 14:20:33 [INFO] train episode 428: winner = 1, steps = 8
# 14:20:34 [INFO] train episode 429: winner = 1, steps = 8
# 14:20:34 [INFO] train episode 430: winner = 1, steps = 8
# 14:20:35 [INFO] train episode 431: winner = 1, steps = 8
# 14:20:35 [INFO] train episode 432: winner = 1, steps = 8
# 14:20:36 [INFO] train episode 433: winner = 1, steps = 8
# 14:20:37 [INFO] train episode 434: winner = 1, steps = 8
# 14:20:38 [INFO] train episode 435: winner = 1, steps = 8
# 14:20:38 [INFO] train episode 436: winner = 1, steps = 8
# 14:20:38 [INFO] train episode 437: winner = 1, steps = 8
# 14:20:39 [INFO] train episode 438: winner = 1, steps = 8
# 14:20:39 [INFO] train episode 439: winner = 1, steps = 8
# 14:20:40 [INFO] train episode 440: winner = 1, steps = 8
# 14:20:40 [INFO] train episode 441: winner = 1, steps = 8
# 14:20:41 [INFO] train episode 442: winner = 1, steps = 8
# 14:20:41 [INFO] train episode 443: winner = 1, steps = 8
# 14:20:41 [INFO] train episode 444: winner = 1, steps = 8
# 14:20:41 [INFO] train episode 445: winner = 1, steps = 8
# 14:20:42 [INFO] train episode 446: winner = 1, steps = 8
# 14:20:43 [INFO] train episode 447: winner = 1, steps = 8
# 14:20:43 [INFO] test episode 447:
# +++
# +++
# +++
# 14:20:44 [INFO] step 0:player 1, action (0, 1)
# +o+
# +++
# +++
# 14:20:45 [INFO] step 1:player -1, action (1, 2)
# +o+
# ++x
# +++
# 14:20:46 [INFO] step 2:player 1, action (2, 0)
# +o+
# ++x
# o++
# 14:20:47 [INFO] step 3:player -1, action (2, 1)
# +o+
# ++x
# ox+
# 14:20:47 [INFO] step 4:player 1, action (1, 1)
# +o+
# +ox
# ox+
# 14:20:47 [INFO] step 5:player -1, action (0, 2)
# +ox
# +ox
# ox+
# 14:20:47 [INFO] step 6:player 1, action (1, 0)
# +ox
# oox
# ox+
# 14:20:47 [INFO] step 7:player -1, action (0, 0)
# xox
# oox
# ox+
# 14:20:47 [INFO] step 8:player 1, action (2, 2)
# xox
# oox
# oxo
# 14:20:47 [INFO] test episode 447: winner = 1, steps = 8
# 14:20:51 [INFO] train episode 448: winner = 1, steps = 8
# 14:20:54 [INFO] train episode 449: winner = 1, steps = 8
# 14:20:55 [INFO] train episode 450: winner = 1, steps = 8
# 14:20:57 [INFO] train episode 451: winner = 1, steps = 8
# 14:20:59 [INFO] train episode 452: winner = 1, steps = 8
# 14:21:01 [INFO] train episode 453: winner = 1, steps = 8
# 14:21:05 [INFO] train episode 454: winner = 1, steps = 8
# 14:21:07 [INFO] train episode 455: winner = 1, steps = 8
# 14:21:08 [INFO] train episode 456: winner = 1, steps = 8
# 14:21:10 [INFO] train episode 457: winner = 1, steps = 8
# 14:21:11 [INFO] train episode 458: winner = 1, steps = 8
# 14:21:12 [INFO] train episode 459: winner = 1, steps = 8
# 14:21:13 [INFO] train episode 460: winner = 1, steps = 8
# 14:21:14 [INFO] train episode 461: winner = 1, steps = 8
# 14:21:15 [INFO] train episode 462: winner = 1, steps = 8
# 14:21:16 [INFO] train episode 463: winner = 1, steps = 8
# 14:21:18 [INFO] train episode 464: winner = 1, steps = 8
# 14:21:19 [INFO] train episode 465: winner = 1, steps = 8
# 14:21:20 [INFO] train episode 466: winner = 1, steps = 8
# 14:21:21 [INFO] train episode 467: winner = 1, steps = 8
# 14:21:22 [INFO] train episode 468: winner = 1, steps = 8
# 14:21:24 [INFO] train episode 469: winner = 1, steps = 8
# 14:21:25 [INFO] train episode 470: winner = 1, steps = 8
# 14:21:26 [INFO] train episode 471: winner = 1, steps = 8
# 14:21:28 [INFO] train episode 472: winner = 1, steps = 8
# 14:21:29 [INFO] train episode 473: winner = 1, steps = 8
# 14:21:30 [INFO] train episode 474: winner = 1, steps = 8
# 14:21:32 [INFO] train episode 475: winner = 1, steps = 8
# 14:21:32 [INFO] train episode 476: winner = 1, steps = 8
# 14:21:33 [INFO] train episode 477: winner = 1, steps = 8
# 14:21:34 [INFO] train episode 478: winner = 1, steps = 8
# 14:21:34 [INFO] train episode 479: winner = 1, steps = 8
# 14:21:35 [INFO] train episode 480: winner = 1, steps = 8
# 14:21:36 [INFO] train episode 481: winner = 1, steps = 8
# 14:21:37 [INFO] train episode 482: winner = 1, steps = 8
# 14:21:38 [INFO] train episode 483: winner = 1, steps = 8
# 14:21:39 [INFO] train episode 484: winner = 1, steps = 8
# 14:21:39 [INFO] train episode 485: winner = 1, steps = 8
# 14:21:40 [INFO] train episode 486: winner = 1, steps = 8
# 14:21:42 [INFO] train episode 487: winner = 1, steps = 8
# 14:21:43 [INFO] train episode 488: winner = 1, steps = 8
# 14:21:44 [INFO] train episode 489: winner = 1, steps = 8
# 14:21:45 [INFO] train episode 490: winner = 1, steps = 8
# 14:21:45 [INFO] train episode 491: winner = 1, steps = 8
# 14:21:46 [INFO] train episode 492: winner = 1, steps = 8
# 14:21:46 [INFO] train episode 493: winner = 1, steps = 8
# 14:21:47 [INFO] train episode 494: winner = 1, steps = 8
# 14:21:48 [INFO] train episode 495: winner = 1, steps = 8
# 14:21:48 [INFO] train episode 496: winner = 1, steps = 8
# 14:21:49 [INFO] train episode 497: winner = 1, steps = 8
# 14:21:49 [INFO] train episode 498: winner = 1, steps = 8
# 14:21:50 [INFO] train episode 499: winner = 1, steps = 8
# 14:21:50 [INFO] train episode 500: winner = 1, steps = 8
# 14:21:51 [INFO] train episode 501: winner = 1, steps = 8
# 14:21:52 [INFO] train episode 502: winner = 1, steps = 8
# 14:21:52 [INFO] train episode 503: winner = 1, steps = 8
# 14:21:53 [INFO] train episode 504: winner = 1, steps = 8
# 14:21:54 [INFO] train episode 505: winner = 1, steps = 8
# 14:21:55 [INFO] train episode 506: winner = 1, steps = 8
# 14:21:56 [INFO] train episode 507: winner = 1, steps = 8
# 14:21:56 [INFO] train episode 508: winner = 1, steps = 8
# 14:21:57 [INFO] train episode 509: winner = 1, steps = 8
# 14:21:58 [INFO] train episode 510: winner = 1, steps = 8
# 14:21:59 [INFO] train episode 511: winner = 1, steps = 8
# 14:21:59 [INFO] train episode 512: winner = 1, steps = 8
# 14:22:00 [INFO] train episode 513: winner = 1, steps = 8
# 14:22:01 [INFO] train episode 514: winner = 1, steps = 8
# 14:22:01 [INFO] train episode 515: winner = 1, steps = 8
# 14:22:02 [INFO] train episode 516: winner = 1, steps = 8
# 14:22:03 [INFO] train episode 517: winner = 1, steps = 8
# 14:22:03 [INFO] train episode 518: winner = 1, steps = 8
# 14:22:04 [INFO] train episode 519: winner = 1, steps = 8
# 14:22:05 [INFO] train episode 520: winner = 1, steps = 8
# 14:22:06 [INFO] train episode 521: winner = 1, steps = 8
# 14:22:06 [INFO] train episode 522: winner = 1, steps = 8
# 14:22:07 [INFO] train episode 523: winner = 1, steps = 8
# 14:22:07 [INFO] train episode 524: winner = 1, steps = 8
# 14:22:07 [INFO] train episode 525: winner = 1, steps = 8
# 14:22:08 [INFO] train episode 526: winner = 1, steps = 8
# 14:22:08 [INFO] train episode 527: winner = 1, steps = 8
# 14:22:08 [INFO] train episode 528: winner = 1, steps = 8
# 14:22:09 [INFO] train episode 529: winner = 1, steps = 8
# 14:22:09 [INFO] train episode 530: winner = 1, steps = 8
# 14:22:09 [INFO] train episode 531: winner = 1, steps = 8
# 14:22:10 [INFO] train episode 532: winner = 1, steps = 8
# 14:22:10 [INFO] train episode 533: winner = 1, steps = 8
# 14:22:10 [INFO] train episode 534: winner = 1, steps = 8
# 14:22:11 [INFO] train episode 535: winner = 1, steps = 8
# 14:22:11 [INFO] train episode 536: winner = 1, steps = 8
# 14:22:12 [INFO] train episode 537: winner = 1, steps = 8
# 14:22:12 [INFO] train episode 538: winner = 1, steps = 8
# 14:22:13 [INFO] train episode 539: winner = 1, steps = 8
# 14:22:14 [INFO] train episode 540: winner = 1, steps = 8
# 14:22:14 [INFO] train episode 541: winner = 1, steps = 8
# 14:22:15 [INFO] train episode 542: winner = 1, steps = 8
# 14:22:15 [INFO] train episode 543: winner = 1, steps = 8
# 14:22:16 [INFO] train episode 544: winner = 1, steps = 8
# 14:22:16 [INFO] train episode 545: winner = 1, steps = 8
# 14:22:17 [INFO] train episode 546: winner = 1, steps = 8
# 14:22:18 [INFO] train episode 547: winner = 1, steps = 8
# 14:22:19 [INFO] train episode 548: winner = 1, steps = 8
# 14:22:19 [INFO] train episode 549: winner = 1, steps = 8
# 14:22:19 [INFO] train episode 550: winner = 1, steps = 8
# 14:22:20 [INFO] train episode 551: winner = 1, steps = 8
# 14:22:20 [INFO] train episode 552: winner = 1, steps = 8
# 14:22:20 [INFO] train episode 553: winner = 1, steps = 8
# 14:22:21 [INFO] train episode 554: winner = 1, steps = 8
# 14:22:22 [INFO] train episode 555: winner = 1, steps = 8
# 14:22:22 [INFO] train episode 556: winner = 1, steps = 8
# 14:22:23 [INFO] train episode 557: winner = 1, steps = 8
# 14:22:23 [INFO] train episode 558: winner = 1, steps = 8
# 14:22:24 [INFO] train episode 559: winner = 1, steps = 8
# 14:22:24 [INFO] test episode 559:
# +++
# +++
# +++
# 14:22:25 [INFO] step 0:player 1, action (2, 1)
# +++
# +++
# +o+
# 14:22:26 [INFO] step 1:player -1, action (1, 2)
# +++
# ++x
# +o+
# 14:22:27 [INFO] step 2:player 1, action (0, 0)
# o++
# ++x
# +o+
# 14:22:28 [INFO] step 3:player -1, action (2, 0)
# o++
# ++x
# xo+
# 14:22:28 [INFO] step 4:player 1, action (1, 1)
# o++
# +ox
# xo+
# 14:22:28 [INFO] step 5:player -1, action (2, 2)
# o++
# +ox
# xox
# 14:22:29 [INFO] step 6:player 1, action (0, 1)
# oo+
# +ox
# xox
# 14:22:29 [INFO] step 7:player -1, action (0, 2)
# oox
# +ox
# xox
# 14:22:29 [INFO] step 8:player 1, action (1, 0)
# oox
# oox
# xox
# 14:22:29 [INFO] test episode 559: winner = 1, steps = 8
# 14:22:32 [INFO] train episode 560: winner = 1, steps = 8
# 14:22:36 [INFO] train episode 561: winner = 1, steps = 8
# 14:22:38 [INFO] train episode 562: winner = 1, steps = 8
# 14:22:39 [INFO] train episode 563: winner = 1, steps = 8
# 14:22:42 [INFO] train episode 564: winner = 1, steps = 8
# 14:22:44 [INFO] train episode 565: winner = 1, steps = 8
# 14:22:46 [INFO] train episode 566: winner = 1, steps = 8
# 14:22:49 [INFO] train episode 567: winner = 1, steps = 8
# 14:22:52 [INFO] train episode 568: winner = 1, steps = 8
# 14:22:53 [INFO] train episode 569: winner = 1, steps = 8
# 14:22:55 [INFO] train episode 570: winner = 1, steps = 8
# 14:22:55 [INFO] train episode 571: winner = 1, steps = 8
# 14:22:57 [INFO] train episode 572: winner = 1, steps = 8
# 14:22:59 [INFO] train episode 573: winner = 1, steps = 8
# 14:23:00 [INFO] train episode 574: winner = 1, steps = 8
# 14:23:01 [INFO] train episode 575: winner = 1, steps = 8
# 14:23:02 [INFO] train episode 576: winner = 1, steps = 8
# 14:23:03 [INFO] train episode 577: winner = 1, steps = 8
# 14:23:03 [INFO] train episode 578: winner = 1, steps = 8
# 14:23:04 [INFO] train episode 579: winner = 1, steps = 8
# 14:23:05 [INFO] train episode 580: winner = 1, steps = 8
# 14:23:06 [INFO] train episode 581: winner = 1, steps = 8
# 14:23:07 [INFO] train episode 582: winner = 1, steps = 8
# 14:23:08 [INFO] train episode 583: winner = 1, steps = 8
# 14:23:09 [INFO] train episode 584: winner = 1, steps = 8
# 14:23:09 [INFO] train episode 585: winner = 1, steps = 8
# 14:23:11 [INFO] train episode 586: winner = 1, steps = 8
# 14:23:11 [INFO] train episode 587: winner = 1, steps = 8
# 14:23:12 [INFO] train episode 588: winner = 1, steps = 8
# 14:23:13 [INFO] train episode 589: winner = 1, steps = 8
# 14:23:14 [INFO] train episode 590: winner = 1, steps = 8
# 14:23:15 [INFO] train episode 591: winner = 1, steps = 8
# 14:23:16 [INFO] train episode 592: winner = 1, steps = 8
# 14:23:16 [INFO] train episode 593: winner = 1, steps = 8
# 14:23:17 [INFO] train episode 594: winner = 1, steps = 8
# 14:23:18 [INFO] train episode 595: winner = 1, steps = 8
# 14:23:19 [INFO] train episode 596: winner = 1, steps = 8
# 14:23:20 [INFO] train episode 597: winner = 1, steps = 8
# 14:23:20 [INFO] train episode 598: winner = 1, steps = 8
# 14:23:21 [INFO] train episode 599: winner = 1, steps = 8
# 14:23:22 [INFO] train episode 600: winner = 1, steps = 8
# 14:23:22 [INFO] train episode 601: winner = 1, steps = 8
# 14:23:23 [INFO] train episode 602: winner = 1, steps = 8
# 14:23:23 [INFO] train episode 603: winner = 1, steps = 8
# 14:23:24 [INFO] train episode 604: winner = 1, steps = 8
# 14:23:25 [INFO] train episode 605: winner = 1, steps = 8
# 14:23:26 [INFO] train episode 606: winner = 1, steps = 8
# 14:23:27 [INFO] train episode 607: winner = 1, steps = 8
# 14:23:28 [INFO] train episode 608: winner = 1, steps = 8
# 14:23:29 [INFO] train episode 609: winner = 1, steps = 8
# 14:23:29 [INFO] train episode 610: winner = 1, steps = 8
# 14:23:30 [INFO] train episode 611: winner = 1, steps = 8
# 14:23:31 [INFO] train episode 612: winner = 1, steps = 8
# 14:23:32 [INFO] train episode 613: winner = 1, steps = 8
# 14:23:32 [INFO] train episode 614: winner = 1, steps = 8
# 14:23:32 [INFO] train episode 615: winner = 1, steps = 8
# 14:23:33 [INFO] train episode 616: winner = 1, steps = 8
# 14:23:34 [INFO] train episode 617: winner = 1, steps = 8
# 14:23:35 [INFO] train episode 618: winner = 1, steps = 8
# 14:23:36 [INFO] train episode 619: winner = 1, steps = 8
# 14:23:37 [INFO] train episode 620: winner = 1, steps = 8
# 14:23:37 [INFO] train episode 621: winner = 1, steps = 8
# 14:23:38 [INFO] train episode 622: winner = 1, steps = 8
# 14:23:38 [INFO] train episode 623: winner = 1, steps = 8
# 14:23:39 [INFO] train episode 624: winner = 1, steps = 8
# 14:23:40 [INFO] train episode 625: winner = 1, steps = 8
# 14:23:41 [INFO] train episode 626: winner = 1, steps = 8
# 14:23:41 [INFO] train episode 627: winner = 1, steps = 8
# 14:23:42 [INFO] train episode 628: winner = 1, steps = 8
# 14:23:43 [INFO] train episode 629: winner = 1, steps = 8
# 14:23:43 [INFO] train episode 630: winner = 1, steps = 8
# 14:23:44 [INFO] train episode 631: winner = 1, steps = 8
# 14:23:44 [INFO] train episode 632: winner = 1, steps = 8
# 14:23:45 [INFO] train episode 633: winner = 1, steps = 8
# 14:23:46 [INFO] train episode 634: winner = 1, steps = 8
# 14:23:46 [INFO] train episode 635: winner = 1, steps = 8
# 14:23:47 [INFO] train episode 636: winner = 1, steps = 8
# 14:23:47 [INFO] train episode 637: winner = 1, steps = 8
# 14:23:48 [INFO] train episode 638: winner = 1, steps = 8
# 14:23:48 [INFO] train episode 639: winner = 1, steps = 8
# 14:23:49 [INFO] train episode 640: winner = 1, steps = 8
# 14:23:49 [INFO] train episode 641: winner = 1, steps = 8
# 14:23:50 [INFO] train episode 642: winner = 1, steps = 8
# 14:23:51 [INFO] train episode 643: winner = 1, steps = 8
# 14:23:52 [INFO] train episode 644: winner = 1, steps = 8
# 14:23:52 [INFO] train episode 645: winner = 1, steps = 8
# 14:23:52 [INFO] train episode 646: winner = 1, steps = 8
# 14:23:53 [INFO] train episode 647: winner = 1, steps = 8
# 14:23:53 [INFO] train episode 648: winner = 1, steps = 8
# 14:23:53 [INFO] train episode 649: winner = 1, steps = 8
# 14:23:54 [INFO] train episode 650: winner = 1, steps = 8
# 14:23:54 [INFO] train episode 651: winner = 1, steps = 8
# 14:23:54 [INFO] train episode 652: winner = 1, steps = 8
# 14:23:55 [INFO] train episode 653: winner = 1, steps = 8
# 14:23:55 [INFO] train episode 654: winner = 1, steps = 8
# 14:23:55 [INFO] train episode 655: winner = 1, steps = 8
# 14:23:56 [INFO] train episode 656: winner = 1, steps = 8
# 14:23:56 [INFO] train episode 657: winner = 1, steps = 8
# 14:23:56 [INFO] train episode 658: winner = 1, steps = 8
# 14:23:57 [INFO] train episode 659: winner = 1, steps = 8
# 14:23:57 [INFO] train episode 660: winner = 1, steps = 8
# 14:23:57 [INFO] train episode 661: winner = 1, steps = 8
# 14:23:58 [INFO] train episode 662: winner = 1, steps = 8
# 14:23:58 [INFO] train episode 663: winner = 1, steps = 8
# 14:23:58 [INFO] train episode 664: winner = 1, steps = 8
# 14:23:59 [INFO] train episode 665: winner = 1, steps = 8
# 14:23:59 [INFO] train episode 666: winner = 1, steps = 8
# 14:24:00 [INFO] train episode 667: winner = 1, steps = 8
# 14:24:01 [INFO] train episode 668: winner = 1, steps = 8
# 14:24:01 [INFO] train episode 669: winner = 1, steps = 8
# 14:24:02 [INFO] train episode 670: winner = 1, steps = 8
# 14:24:02 [INFO] train episode 671: winner = 1, steps = 8
# 14:24:02 [INFO] test episode 671:
# +++
# +++
# +++
# 14:24:04 [INFO] step 0:player 1, action (1, 1)
# +++
# +o+
# +++
# 14:24:05 [INFO] step 1:player -1, action (0, 0)
# x++
# +o+
# +++
# 14:24:06 [INFO] step 2:player 1, action (0, 2)
# x+o
# +o+
# +++
# 14:24:07 [INFO] step 3:player -1, action (2, 2)
# x+o
# +o+
# ++x
# 14:24:07 [INFO] step 4:player 1, action (1, 0)
# x+o
# oo+
# ++x
# 14:24:07 [INFO] step 5:player -1, action (1, 2)
# x+o
# oox
# ++x
# 14:24:07 [INFO] step 6:player 1, action (0, 1)
# xoo
# oox
# ++x
# 14:24:07 [INFO] step 7:player -1, action (2, 0)
# xoo
# oox
# x+x
# 14:24:07 [INFO] step 8:player 1, action (2, 1)
# xoo
# oox
# xox
# 14:24:07 [INFO] test episode 671: winner = 1, steps = 8
# 14:24:10 [INFO] train episode 672: winner = 1, steps = 8
# 14:24:13 [INFO] train episode 673: winner = 1, steps = 8
# 14:24:16 [INFO] train episode 674: winner = 1, steps = 8
# 14:24:18 [INFO] train episode 675: winner = 1, steps = 8
# 14:24:20 [INFO] train episode 676: winner = 1, steps = 8
# 14:24:21 [INFO] train episode 677: winner = 1, steps = 8
# 14:24:24 [INFO] train episode 678: winner = 1, steps = 8
# 14:24:26 [INFO] train episode 679: winner = 1, steps = 8
# 14:24:28 [INFO] train episode 680: winner = 1, steps = 8
# 14:24:29 [INFO] train episode 681: winner = 1, steps = 8
# 14:24:30 [INFO] train episode 682: winner = 1, steps = 8
# 14:24:33 [INFO] train episode 683: winner = 1, steps = 8
# 14:24:34 [INFO] train episode 684: winner = 1, steps = 8
# 14:24:35 [INFO] train episode 685: winner = 1, steps = 8
# 14:24:36 [INFO] train episode 686: winner = 1, steps = 8
# 14:24:37 [INFO] train episode 687: winner = 1, steps = 8
# 14:24:37 [INFO] train episode 688: winner = 1, steps = 8
# 14:24:38 [INFO] train episode 689: winner = 1, steps = 8
# 14:24:39 [INFO] train episode 690: winner = 1, steps = 8
# 14:24:40 [INFO] train episode 691: winner = 1, steps = 8
# 14:24:41 [INFO] train episode 692: winner = 1, steps = 8
# 14:24:42 [INFO] train episode 693: winner = 1, steps = 8
# 14:24:43 [INFO] train episode 694: winner = 1, steps = 8
# 14:24:44 [INFO] train episode 695: winner = 1, steps = 8
# 14:24:45 [INFO] train episode 696: winner = 1, steps = 8
# 14:24:45 [INFO] train episode 697: winner = 1, steps = 8
# 14:24:46 [INFO] train episode 698: winner = 1, steps = 8
# 14:24:47 [INFO] train episode 699: winner = 1, steps = 8
# 14:24:49 [INFO] train episode 700: winner = 1, steps = 8
# 14:24:50 [INFO] train episode 701: winner = 1, steps = 8
# 14:24:50 [INFO] train episode 702: winner = 1, steps = 8
# 14:24:51 [INFO] train episode 703: winner = 1, steps = 8
# 14:24:53 [INFO] train episode 704: winner = 1, steps = 8
# 14:24:54 [INFO] train episode 705: winner = 1, steps = 8
# 14:24:54 [INFO] train episode 706: winner = 1, steps = 8
# 14:24:55 [INFO] train episode 707: winner = 1, steps = 8
# 14:24:55 [INFO] train episode 708: winner = 1, steps = 8
# 14:24:56 [INFO] train episode 709: winner = 1, steps = 8
# 14:24:57 [INFO] train episode 710: winner = 1, steps = 8
# 14:24:57 [INFO] train episode 711: winner = 1, steps = 8
# 14:24:58 [INFO] train episode 712: winner = 1, steps = 8
# 14:24:59 [INFO] train episode 713: winner = 1, steps = 8
# 14:25:00 [INFO] train episode 714: winner = 1, steps = 8
# 14:25:00 [INFO] train episode 715: winner = 1, steps = 8
# 14:25:01 [INFO] train episode 716: winner = 1, steps = 8
# 14:25:02 [INFO] train episode 717: winner = 1, steps = 8
# 14:25:02 [INFO] train episode 718: winner = 1, steps = 8
# 14:25:04 [INFO] train episode 719: winner = 1, steps = 8
# 14:25:04 [INFO] train episode 720: winner = 1, steps = 8
# 14:25:04 [INFO] train episode 721: winner = 1, steps = 8
# 14:25:05 [INFO] train episode 722: winner = 1, steps = 8
# 14:25:05 [INFO] train episode 723: winner = 1, steps = 8
# 14:25:07 [INFO] train episode 724: winner = 1, steps = 8
# 14:25:08 [INFO] train episode 725: winner = 1, steps = 8
# 14:25:09 [INFO] train episode 726: winner = 1, steps = 8
# 14:25:09 [INFO] train episode 727: winner = 1, steps = 8
# 14:25:10 [INFO] train episode 728: winner = 1, steps = 8
# 14:25:10 [INFO] train episode 729: winner = 1, steps = 8
# 14:25:11 [INFO] train episode 730: winner = 1, steps = 8
# 14:25:11 [INFO] train episode 731: winner = 1, steps = 8
# 14:25:12 [INFO] train episode 732: winner = 1, steps = 8
# 14:25:13 [INFO] train episode 733: winner = 1, steps = 8
# 14:25:14 [INFO] train episode 734: winner = 1, steps = 8
# 14:25:15 [INFO] train episode 735: winner = 1, steps = 8
# 14:25:15 [INFO] train episode 736: winner = 1, steps = 8
# 14:25:16 [INFO] train episode 737: winner = 1, steps = 8
# 14:25:16 [INFO] train episode 738: winner = 1, steps = 8
# 14:25:17 [INFO] train episode 739: winner = 1, steps = 8
# 14:25:18 [INFO] train episode 740: winner = 1, steps = 8
# 14:25:18 [INFO] train episode 741: winner = 1, steps = 8
# 14:25:19 [INFO] train episode 742: winner = 1, steps = 8
# 14:25:19 [INFO] train episode 743: winner = 1, steps = 8
# 14:25:20 [INFO] train episode 744: winner = 1, steps = 8
# 14:25:21 [INFO] train episode 745: winner = 1, steps = 8
# 14:25:21 [INFO] train episode 746: winner = 1, steps = 8
# 14:25:21 [INFO] train episode 747: winner = 1, steps = 8
# 14:25:22 [INFO] train episode 748: winner = 1, steps = 8
# 14:25:22 [INFO] train episode 749: winner = 1, steps = 8
# 14:25:22 [INFO] train episode 750: winner = 1, steps = 8
# 14:25:23 [INFO] train episode 751: winner = 1, steps = 8
# 14:25:23 [INFO] train episode 752: winner = 1, steps = 8
# 14:25:25 [INFO] train episode 753: winner = 1, steps = 8
# 14:25:26 [INFO] train episode 754: winner = 1, steps = 8
# 14:25:26 [INFO] train episode 755: winner = 1, steps = 8
# 14:25:26 [INFO] train episode 756: winner = 1, steps = 8
# 14:25:27 [INFO] train episode 757: winner = 1, steps = 8
# 14:25:27 [INFO] train episode 758: winner = 1, steps = 8
# 14:25:28 [INFO] train episode 759: winner = 1, steps = 8
# 14:25:29 [INFO] train episode 760: winner = 1, steps = 8
# 14:25:29 [INFO] train episode 761: winner = 1, steps = 8
# 14:25:30 [INFO] train episode 762: winner = 1, steps = 8
# 14:25:30 [INFO] train episode 763: winner = 1, steps = 8
# 14:25:32 [INFO] train episode 764: winner = 1, steps = 8
# 14:25:32 [INFO] train episode 765: winner = 1, steps = 8
# 14:25:32 [INFO] train episode 766: winner = 1, steps = 8
# 14:25:33 [INFO] train episode 767: winner = 1, steps = 8
# 14:25:34 [INFO] train episode 768: winner = 1, steps = 8
# 14:25:35 [INFO] train episode 769: winner = 1, steps = 8
# 14:25:35 [INFO] train episode 770: winner = 1, steps = 8
# 14:25:35 [INFO] train episode 771: winner = 1, steps = 8
# 14:25:36 [INFO] train episode 772: winner = 1, steps = 8
# 14:25:37 [INFO] train episode 773: winner = 1, steps = 8
# 14:25:37 [INFO] train episode 774: winner = 1, steps = 8
# 14:25:37 [INFO] train episode 775: winner = 1, steps = 8
# ...
# 15:16:40 [INFO] train episode 4368: winner = 1, steps = 8
# 15:16:42 [INFO] train episode 4369: winner = 1, steps = 8
# 15:16:44 [INFO] train episode 4370: winner = 1, steps = 8
# 15:16:46 [INFO] train episode 4371: winner = 1, steps = 8
# 15:16:48 [INFO] train episode 4372: winner = 1, steps = 8
# 15:16:49 [INFO] train episode 4373: winner = 1, steps = 8
# 15:16:50 [INFO] train episode 4374: winner = 1, steps = 8
# 15:16:51 [INFO] train episode 4375: winner = 1, steps = 8
# 15:16:52 [INFO] train episode 4376: winner = 1, steps = 8
# 15:16:52 [INFO] train episode 4377: winner = 1, steps = 8
# 15:16:53 [INFO] train episode 4378: winner = 1, steps = 8
# 15:16:54 [INFO] train episode 4379: winner = 1, steps = 8
# 15:16:55 [INFO] train episode 4380: winner = 1, steps = 8
# 15:16:55 [INFO] train episode 4381: winner = 1, steps = 8
# 15:16:57 [INFO] train episode 4382: winner = 1, steps = 8
# 15:16:57 [INFO] train episode 4383: winner = 1, steps = 8
# 15:16:58 [INFO] train episode 4384: winner = 1, steps = 8
# 15:16:59 [INFO] train episode 4385: winner = 1, steps = 8
# 15:16:59 [INFO] train episode 4386: winner = 1, steps = 8
# 15:17:00 [INFO] train episode 4387: winner = 1, steps = 8
# 15:17:00 [INFO] train episode 4388: winner = 1, steps = 8
# 15:17:01 [INFO] train episode 4389: winner = 1, steps = 8
# 15:17:01 [INFO] train episode 4390: winner = 1, steps = 8
# 15:17:01 [INFO] train episode 4391: winner = 1, steps = 8
# 15:17:03 [INFO] train episode 4392: winner = 1, steps = 8
# 15:17:03 [INFO] train episode 4393: winner = 1, steps = 8
# 15:17:03 [INFO] train episode 4394: winner = 1, steps = 8
# 15:17:04 [INFO] train episode 4395: winner = 1, steps = 8
# 15:17:04 [INFO] train episode 4396: winner = 1, steps = 8
# 15:17:04 [INFO] train episode 4397: winner = 1, steps = 8
# 15:17:05 [INFO] train episode 4398: winner = 1, steps = 8
# 15:17:06 [INFO] train episode 4399: winner = 1, steps = 8
# 15:17:07 [INFO] train episode 4400: winner = 1, steps = 8
# 15:17:08 [INFO] train episode 4401: winner = 1, steps = 8
# 15:17:08 [INFO] train episode 4402: winner = 1, steps = 8
# 15:17:09 [INFO] train episode 4403: winner = 1, steps = 8
# 15:17:10 [INFO] train episode 4404: winner = 1, steps = 8
# 15:17:10 [INFO] train episode 4405: winner = 1, steps = 8
# 15:17:10 [INFO] train episode 4406: winner = 1, steps = 8
# 15:17:10 [INFO] train episode 4407: winner = 1, steps = 8
# 15:17:11 [INFO] train episode 4408: winner = 1, steps = 8
# 15:17:11 [INFO] train episode 4409: winner = 1, steps = 8
# 15:17:12 [INFO] train episode 4410: winner = 1, steps = 8
# 15:17:12 [INFO] train episode 4411: winner = 1, steps = 8
# 15:17:12 [INFO] train episode 4412: winner = 1, steps = 8
# 15:17:13 [INFO] train episode 4413: winner = 1, steps = 8
# 15:17:13 [INFO] train episode 4414: winner = 1, steps = 8
# 15:17:14 [INFO] train episode 4415: winner = 1, steps = 8
# 15:17:14 [INFO] train episode 4416: winner = 1, steps = 8
# 15:17:15 [INFO] train episode 4417: winner = 1, steps = 8
# 15:17:15 [INFO] train episode 4418: winner = 1, steps = 8
# 15:17:15 [INFO] train episode 4419: winner = 1, steps = 8
# 15:17:16 [INFO] train episode 4420: winner = 1, steps = 8
# 15:17:17 [INFO] train episode 4421: winner = 1, steps = 8
# 15:17:17 [INFO] train episode 4422: winner = 1, steps = 8
# 15:17:18 [INFO] train episode 4423: winner = 1, steps = 8
# 15:17:19 [INFO] train episode 4424: winner = 1, steps = 8
# 15:17:19 [INFO] train episode 4425: winner = 1, steps = 8
# 15:17:20 [INFO] train episode 4426: winner = 1, steps = 8
# 15:17:20 [INFO] train episode 4427: winner = 1, steps = 8
# 15:17:21 [INFO] train episode 4428: winner = 1, steps = 8
# 15:17:21 [INFO] train episode 4429: winner = 1, steps = 8
# 15:17:21 [INFO] train episode 4430: winner = 1, steps = 8
# 15:17:22 [INFO] train episode 4431: winner = 1, steps = 8
# 15:17:22 [INFO] train episode 4432: winner = 1, steps = 8
# 15:17:22 [INFO] train episode 4433: winner = 1, steps = 8
# 15:17:23 [INFO] train episode 4434: winner = 1, steps = 8
# 15:17:23 [INFO] train episode 4435: winner = 1, steps = 8
# 15:17:23 [INFO] train episode 4436: winner = 1, steps = 8
# 15:17:24 [INFO] train episode 4437: winner = 1, steps = 8
# 15:17:24 [INFO] train episode 4438: winner = 1, steps = 8
# 15:17:24 [INFO] train episode 4439: winner = 1, steps = 8
# 15:17:25 [INFO] train episode 4440: winner = 1, steps = 8
# 15:17:25 [INFO] train episode 4441: winner = 1, steps = 8
# 15:17:26 [INFO] train episode 4442: winner = 1, steps = 8
# 15:17:26 [INFO] train episode 4443: winner = 1, steps = 8
# 15:17:27 [INFO] train episode 4444: winner = 1, steps = 8
# 15:17:27 [INFO] train episode 4445: winner = 1, steps = 8
# 15:17:27 [INFO] train episode 4446: winner = 1, steps = 8
# 15:17:28 [INFO] train episode 4447: winner = 1, steps = 8
# 15:17:28 [INFO] train episode 4448: winner = 1, steps = 8
# 15:17:29 [INFO] train episode 4449: winner = 1, steps = 8
# 15:17:29 [INFO] train episode 4450: winner = 1, steps = 8
# 15:17:30 [INFO] train episode 4451: winner = 1, steps = 8
# 15:17:30 [INFO] train episode 4452: winner = 1, steps = 8
# 15:17:30 [INFO] train episode 4453: winner = 1, steps = 8
# 15:17:30 [INFO] train episode 4454: winner = 1, steps = 8
# 15:17:31 [INFO] train episode 4455: winner = 1, steps = 8
# 15:17:31 [INFO] train episode 4456: winner = 1, steps = 8
# 15:17:31 [INFO] train episode 4457: winner = 1, steps = 8
# 15:17:32 [INFO] train episode 4458: winner = 1, steps = 8
# 15:17:32 [INFO] train episode 4459: winner = 1, steps = 8
# 15:17:33 [INFO] train episode 4460: winner = 1, steps = 8
# 15:17:33 [INFO] train episode 4461: winner = 1, steps = 8
# 15:17:33 [INFO] train episode 4462: winner = 1, steps = 8
# 15:17:34 [INFO] train episode 4463: winner = 1, steps = 8
# 15:17:34 [INFO] train episode 4464: winner = 1, steps = 8
# 15:17:35 [INFO] train episode 4465: winner = 1, steps = 8
# 15:17:35 [INFO] train episode 4466: winner = 1, steps = 8
# 15:17:35 [INFO] train episode 4467: winner = 1, steps = 8
# 15:17:35 [INFO] train episode 4468: winner = 1, steps = 8
# 15:17:36 [INFO] train episode 4469: winner = 1, steps = 8
# 15:17:36 [INFO] train episode 4470: winner = 1, steps = 8
# 15:17:36 [INFO] train episode 4471: winner = 1, steps = 8
# 15:17:37 [INFO] train episode 4472: winner = 1, steps = 8
# 15:17:37 [INFO] train episode 4473: winner = 1, steps = 8
# 15:17:37 [INFO] train episode 4474: winner = 1, steps = 8
# 15:17:37 [INFO] train episode 4475: winner = 1, steps = 8
# 15:17:38 [INFO] train episode 4476: winner = 1, steps = 8
# 15:17:38 [INFO] train episode 4477: winner = 1, steps = 8
# 15:17:39 [INFO] train episode 4478: winner = 1, steps = 8
# 15:17:40 [INFO] train episode 4479: winner = 1, steps = 8
# 15:17:40 [INFO] test episode 4479:
# +++
# +++
# +++
# 15:17:41 [INFO] step 0:player 1, action (2, 1)
# +++
# +++
# +o+
# 15:17:41 [INFO] step 1:player -1, action (1, 2)
# +++
# ++x
# +o+
# 15:17:42 [INFO] step 2:player 1, action (0, 1)
# +o+
# ++x
# +o+
# 15:17:43 [INFO] step 3:player -1, action (0, 2)
# +ox
# ++x
# +o+
# 15:17:43 [INFO] step 4:player 1, action (2, 0)
# +ox
# ++x
# oo+
# 15:17:43 [INFO] step 5:player -1, action (1, 1)
# +ox
# +xx
# oo+
# 15:17:43 [INFO] step 6:player 1, action (2, 2)
# +ox
# +xx
# ooo
# 15:17:44 [INFO] step 7:player -1, action (1, 0)
# +ox
# xxx
# ooo
# 15:17:44 [INFO] step 8:player 1, action (0, 0)
# oox
# xxx
# ooo
# 15:17:44 [INFO] test episode 4479: winner = 1, steps = 8
# 15:17:46 [INFO] train episode 4480: winner = 1, steps = 8
# 15:17:48 [INFO] train episode 4481: winner = 1, steps = 8
# 15:17:50 [INFO] train episode 4482: winner = 1, steps = 8
# 15:17:52 [INFO] train episode 4483: winner = 1, steps = 8
# 15:17:52 [INFO] train episode 4484: winner = 1, steps = 8
# 15:17:54 [INFO] train episode 4485: winner = 1, steps = 8
# 15:17:55 [INFO] train episode 4486: winner = 1, steps = 8
# 15:17:57 [INFO] train episode 4487: winner = 1, steps = 8
# 15:17:57 [INFO] train episode 4488: winner = 1, steps = 8
# 15:17:58 [INFO] train episode 4489: winner = 1, steps = 8
# 15:18:00 [INFO] train episode 4490: winner = 1, steps = 8
# 15:18:00 [INFO] train episode 4491: winner = 1, steps = 8
# 15:18:02 [INFO] train episode 4492: winner = 1, steps = 8
# 15:18:02 [INFO] train episode 4493: winner = 1, steps = 8
# 15:18:03 [INFO] train episode 4494: winner = 1, steps = 8
# 15:18:04 [INFO] train episode 4495: winner = 1, steps = 8
# 15:18:05 [INFO] train episode 4496: winner = 1, steps = 8
# 15:18:05 [INFO] train episode 4497: winner = 1, steps = 8
# 15:18:05 [INFO] train episode 4498: winner = 1, steps = 8
# 15:18:06 [INFO] train episode 4499: winner = 1, steps = 8
# 15:18:08 [INFO] train episode 4500: winner = 1, steps = 8
# 15:18:08 [INFO] train episode 4501: winner = 1, steps = 8
# 15:18:09 [INFO] train episode 4502: winner = 1, steps = 8
# 15:18:10 [INFO] train episode 4503: winner = 1, steps = 8
# 15:18:10 [INFO] train episode 4504: winner = 1, steps = 8
# 15:18:11 [INFO] train episode 4505: winner = 1, steps = 8
# 15:18:11 [INFO] train episode 4506: winner = 1, steps = 8
# 15:18:12 [INFO] train episode 4507: winner = 1, steps = 8
# 15:18:12 [INFO] train episode 4508: winner = 1, steps = 8
# 15:18:13 [INFO] train episode 4509: winner = 1, steps = 8
# 15:18:13 [INFO] train episode 4510: winner = 1, steps = 8
# 15:18:14 [INFO] train episode 4511: winner = 1, steps = 8
# 15:18:14 [INFO] train episode 4512: winner = 1, steps = 8
# 15:18:15 [INFO] train episode 4513: winner = 1, steps = 8
# 15:18:16 [INFO] train episode 4514: winner = 1, steps = 8
# 15:18:17 [INFO] train episode 4515: winner = 1, steps = 8
# 15:18:17 [INFO] train episode 4516: winner = 1, steps = 8
# 15:18:18 [INFO] train episode 4517: winner = 1, steps = 8
# 15:18:19 [INFO] train episode 4518: winner = 1, steps = 8
# 15:18:19 [INFO] train episode 4519: winner = 1, steps = 8
# 15:18:19 [INFO] train episode 4520: winner = 1, steps = 8
# 15:18:20 [INFO] train episode 4521: winner = 1, steps = 8
# 15:18:20 [INFO] train episode 4522: winner = 1, steps = 8
# 15:18:21 [INFO] train episode 4523: winner = 1, steps = 8
# 15:18:21 [INFO] train episode 4524: winner = 1, steps = 8
# 15:18:21 [INFO] train episode 4525: winner = 1, steps = 8
# 15:18:22 [INFO] train episode 4526: winner = 1, steps = 8
# 15:18:22 [INFO] train episode 4527: winner = 1, steps = 8
# 15:18:23 [INFO] train episode 4528: winner = 1, steps = 8
# 15:18:23 [INFO] train episode 4529: winner = 1, steps = 8
# 15:18:23 [INFO] train episode 4530: winner = 1, steps = 8
# 15:18:23 [INFO] train episode 4531: winner = 1, steps = 8
# 15:18:24 [INFO] train episode 4532: winner = 1, steps = 8
# 15:18:24 [INFO] train episode 4533: winner = 1, steps = 8
# 15:18:25 [INFO] train episode 4534: winner = 1, steps = 8
# 15:18:25 [INFO] train episode 4535: winner = 1, steps = 8
# 15:18:26 [INFO] train episode 4536: winner = 1, steps = 8
# 15:18:26 [INFO] train episode 4537: winner = 1, steps = 8
# 15:18:26 [INFO] train episode 4538: winner = 1, steps = 8
# 15:18:27 [INFO] train episode 4539: winner = 1, steps = 8
# 15:18:27 [INFO] train episode 4540: winner = 1, steps = 8
# 15:18:28 [INFO] train episode 4541: winner = 1, steps = 8
# 15:18:28 [INFO] train episode 4542: winner = 1, steps = 8
# 15:18:28 [INFO] train episode 4543: winner = 1, steps = 8
# 15:18:29 [INFO] train episode 4544: winner = 1, steps = 8
# 15:18:29 [INFO] train episode 4545: winner = 1, steps = 8
# 15:18:29 [INFO] train episode 4546: winner = 1, steps = 8
# 15:18:30 [INFO] train episode 4547: winner = 1, steps = 8
# 15:18:30 [INFO] train episode 4548: winner = 1, steps = 8
# 15:18:30 [INFO] train episode 4549: winner = 1, steps = 8
# 15:18:30 [INFO] train episode 4550: winner = 1, steps = 8
# 15:18:31 [INFO] train episode 4551: winner = 1, steps = 8
# 15:18:31 [INFO] train episode 4552: winner = 1, steps = 8
# 15:18:31 [INFO] train episode 4553: winner = 1, steps = 8
# 15:18:32 [INFO] train episode 4554: winner = 1, steps = 8
# 15:18:32 [INFO] train episode 4555: winner = 1, steps = 8
# 15:18:32 [INFO] train episode 4556: winner = 1, steps = 8
# 15:18:33 [INFO] train episode 4557: winner = 1, steps = 8
# 15:18:34 [INFO] train episode 4558: winner = 1, steps = 8
# 15:18:34 [INFO] train episode 4559: winner = 1, steps = 8
# 15:18:34 [INFO] train episode 4560: winner = 1, steps = 8
# 15:18:34 [INFO] train episode 4561: winner = 1, steps = 8
# 15:18:35 [INFO] train episode 4562: winner = 1, steps = 8
# 15:18:35 [INFO] train episode 4563: winner = 1, steps = 8
# 15:18:35 [INFO] train episode 4564: winner = 1, steps = 8
# 15:18:36 [INFO] train episode 4565: winner = 1, steps = 8
# 15:18:37 [INFO] train episode 4566: winner = 1, steps = 8
# 15:18:37 [INFO] train episode 4567: winner = 1, steps = 8
# 15:18:38 [INFO] train episode 4568: winner = 1, steps = 8
# 15:18:38 [INFO] train episode 4569: winner = 1, steps = 8
# 15:18:38 [INFO] train episode 4570: winner = 1, steps = 8
# 15:18:38 [INFO] train episode 4571: winner = 1, steps = 8
# 15:18:39 [INFO] train episode 4572: winner = 1, steps = 8
# 15:18:39 [INFO] train episode 4573: winner = 1, steps = 8
# 15:18:40 [INFO] train episode 4574: winner = 1, steps = 8
# 15:18:40 [INFO] train episode 4575: winner = 1, steps = 8
# 15:18:40 [INFO] train episode 4576: winner = 1, steps = 8
# 15:18:40 [INFO] train episode 4577: winner = 1, steps = 8
# 15:18:41 [INFO] train episode 4578: winner = 1, steps = 8
# 15:18:41 [INFO] train episode 4579: winner = 1, steps = 8
# 15:18:42 [INFO] train episode 4580: winner = 1, steps = 8
# 15:18:42 [INFO] train episode 4581: winner = 1, steps = 8
# 15:18:42 [INFO] train episode 4582: winner = 1, steps = 8
# 15:18:43 [INFO] train episode 4583: winner = 1, steps = 8
# 15:18:43 [INFO] train episode 4584: winner = 1, steps = 8
# 15:18:44 [INFO] train episode 4585: winner = 1, steps = 8
# 15:18:44 [INFO] train episode 4586: winner = 1, steps = 8
# 15:18:45 [INFO] train episode 4587: winner = 1, steps = 8
# 15:18:45 [INFO] train episode 4588: winner = 1, steps = 8
# 15:18:46 [INFO] train episode 4589: winner = 1, steps = 8
# 15:18:46 [INFO] train episode 4590: winner = 1, steps = 8
# 15:18:47 [INFO] train episode 4591: winner = 1, steps = 8
# 15:18:47 [INFO] test episode 4591:
# +++
# +++
# +++
# 15:18:48 [INFO] step 0:player 1, action (2, 2)
# +++
# +++
# ++o
# 15:18:49 [INFO] step 1:player -1, action (1, 2)
# +++
# ++x
# ++o
# 15:18:50 [INFO] step 2:player 1, action (0, 2)
# ++o
# ++x
# ++o
# 15:18:50 [INFO] step 3:player -1, action (0, 1)
# +xo
# ++x
# ++o
# 15:18:50 [INFO] step 4:player 1, action (0, 0)
# oxo
# ++x
# ++o
# 15:18:51 [INFO] step 5:player -1, action (2, 1)
# oxo
# ++x
# +xo
# 15:18:51 [INFO] step 6:player 1, action (1, 0)
# oxo
# o+x
# +xo
# 15:18:51 [INFO] step 7:player -1, action (1, 1)
# oxo
# oxx
# +xo
# 15:18:51 [INFO] step 8:player 1, action (2, 0)
# oxo
# oxx
# oxo
# 15:18:51 [INFO] test episode 4591: winner = 1, steps = 8
# 15:18:53 [INFO] train episode 4592: winner = 1, steps = 8
# 15:18:55 [INFO] train episode 4593: winner = 1, steps = 8
# 15:18:58 [INFO] train episode 4594: winner = 1, steps = 8
# 15:18:59 [INFO] train episode 4595: winner = 1, steps = 8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2001/2447729788.py in <module>
#      23
#      24 for episode in range(5000):
# ---> 25     winner, elapsed_steps = play_boardgame2_episode(env, agent, mode="train")
#      26     logging.info('train episode %d: winner = %d, steps = %d', episode, winner, elapsed_steps)
#      27
#
# /tmp/ipykernel_2001/2447729788.py in play_boardgame2_episode(env, agent, mode, verbose)
#       7             board, player = observation
#       8             print(boardgame2.strfboard(board))
# ----> 9         action = agent.step(observation, winner, done)
#      10         if verbose:
#      11             logging.info("step %d:player %d, action %s", elapsed_steps, player, action)
#
# /tmp/ipykernel_2001/3542198239.py in step(self, observation, winner, _)
#      35         s = boardgame2.strfboard(canonical_board)
#      36         while self.count[s].sum() < 200: # conduct MCTS 200 times
# ---> 37             self.search(canonical_board, prior_noise=True)
#      38         prob = self.count[s] / self.count[s].sum()
#      39
#
# /tmp/ipykernel_2001/3542198239.py in search(self, board, prior_noise)
#      96         if prior_noise:
#      97             alpha = 1. / self.valid[s].sum()
# ---> 98             noise = np.random.gamma(alpha, 1., board.shape)
#      99             noise *= self.valid[s]
#     100             noise /= noise.sum()
#
# KeyboardInterrupt:
